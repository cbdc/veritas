# %%
from IPython.display import HTML

HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
<form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# <form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>

# %% [markdown]
# # Processing spectra from VERITAS database

# %% [markdown]
# In this notebook we will structure the pipeline to process the publicly available
# [VERITAS blazars spectra][VDB].
# The goal is to collect the (ascii) data files at the bottom [that page][VDB],
# transform and structure them to VO-compliant data structures.
# Also, flux data should be standardized to [CGS][CGS] units $erg.s^{-1}.cm^{-2}$,
# and wavelength/frequency to $Hz$.
#
# [VDB]: http://veritas.sao.arizona.edu/veritas-science/veritas-blazar-spectra
# [CGS]: https://en.wikipedia.org/wiki/Centimetre%E2%80%93gram%E2%80%93second_system_of_units
#
# The table of interest at the [VERITAS page][VDB] is the last one on that page -- which we'll call here
# *target table* --, where we have the columns:
#
# | Blazar | Publication | VERITAS results page | Ascii file with spectral data |
# |--------|-------------|----------------------|-------------------------------|
# | ...    | ...         | ...                  | ...                           |
#
# Where,
# * `Blazar` contains the name of the object and possibly a qualifier about blazar state of activity in parenthesis after the name (as the example). This column is *not* unique!
# * `Publication` is neither an unique column and contains the identifier of the article where the respective data was published; this is *not* a link or a standard (e.g, DOI) value.
# * `VERITAS results page` contains links to another (internal) page where plots of the article are provided; the link to the `ArXiv` version of the article is there provided
# * `Ascii file with spectral data` are links to the data table.
#
# The ASCII files have the following structure (follow the head line of those files):
# ```
#     //VHE points: E[TeV] phi[m-2 s-1 TeV-1] ephi_low ephi_up
# ```
#
# All files have the same head line, which means that all tables have the same metadata, which means that column order and units are all the same!
#
# **AlreadyGood**:
# * data files have all the same structure, same metadata, same units;
#
# **ToImprove**:
# * `Blazars` column should contain *only* the object name, o//VHE points: E[TeV] phi[m-2 s-1 TeV-1] ephi_low ephi_upbservations like the object's state of activity (e.g, high/low) are better to go in another column;
# * `MJD` can be added as an extra column;
# * `Publication` could be label as it is, but a hyperlink to ArXiv;
#
# <div style="margin-top:30px; margin-bottom:30px;
#             background-color:orange; color:black; opacity:0.75; padding:10px;">
#     Each data file is assumed to be the result of <b>one</b>, contiguous observation.
# </div>
#
#
# The final result we are looking for is a master table with:
#
# | Blazar name | ICRS position (x2) | MJD (x2) | Publication (hyperlink) | Data file (FITS) | Note |
# |-------------|--------------------|----------|-------------------------|------------------|------|
# | ...         | (RA & Dec)         | (Start & End) | (ArXiv)            | ...              | ...  |
#
#
# The `ICRS position` is **not** provided, we have to query [Simbad][SIMBAD] for it.
#
# `MJD` (epoch) is not directly provided either, but we should probably get them from the other
# tables at the [same page][VDB], or create another, local table from the articles.
#
# `Publication` (the ArXiv) link should be parsed from the related page provided by the
# *target table*'s `Publication` column.
#
# Finally, `Blazar name` and `Note` is already given and `Data file` will be the result of inputs formatting.
#
# [SIMBAD]: http://simbad.u-strasbg.fr/simbad/
#
# The results of this processing are publicly available through a [Virtual Observatory (VO)][IVOA]
# compatible framework at the [Brazilian Science Data Center (BSDC)][BSDCVO].
# A [web interface][BSDCWEB] and a [SSAP service][BSDCSAP] are provided for accesing the data.
#
# [IVOA]: http://www.ivoa.net/
# [BSDCVO]: http://vo.bsdc.icranet.org/
# [BSDCWEB]: http://vo.bsdc.icranet.org/veritas/q/web/form
# [BSDCSAP]: http://vo.bsdc.icranet.org/veritas/q/ssa/info

# %% [markdown]
# ## The workflow
#
# Here goes the workflow we shoud code below:
#
# 1. Retrieve the 'target table' from 'http://veritas.sao.arizona.edu/veritas-science/veritas-blazar-spectra'
# 1. Parse each line onto
#  * object name
#  * note
#  * publication "bibcode"
#  * results url
#  * data url
#  * **Process data file**
# 1. Create the output table
#
# *Process data file*:
# 1. retrieve ICRS position from object name
# 1. parse results page to get publication's ArXiv link
# 1. download ascii data file
#  * transform first column, `E`, from $TeV$ to $Hz$
#  * transform second column, `phi`, from $m^{-2} s^{-1} TeV^{-1}$ to $erg s^{-1} cm^{-2}$
#  * transform 3rd and 4st columns, `ephi_low` and `ephi_up`, as done for `phi`
#  * associate those columns with proper UCDs
# 1. write everything in a FITS file

# %%
# import pandas
# import wget
# import bs4

def eprint(string):
#     from sys import stderr
#     print >> stderr, "{}".format(string)
#     stderr.flush()
    print "\nERROR:{}".format(string)

# %%
class HTMLBase(object):
    fields = {}

    def __init__(self,html):
        self._html = html

    def html(self):
        return self._html

    def extract_fields(self):
        assert False, "Not implemented. This is a base class."

def process_row(row,fields,get_doi=False):
    cells = row.findAll('td')
    if len(cells)==4:
        # Object source name(s) (can be more then one comma separated)
        _i_ = fields['Blazar']
        src = cells[_i_].find(text=True)
        src = src.strip()
        # Article reference (url), usually a ref to ads
        _i_ = fields['VERITAS results page']
        art = cells[_i_].find('a',href=True)
        url = art['href']
        if get_doi:
            url = get_doi_url(url)
        # We skip year of publication (third column)
        # as well as bibcode reference (fourth column)
        #ref = cells[3].find(text=True).encode('utf8')
        # FITS file link for downloading it in the near future
        _i_ = fields['Ascii file with spectral data']
        fits = cells[_i_]
        ffile = fits.find('a',href=True)
        try:
            ffile = ffile['href']
        except:
            ffile = None
        #furl = url+ffile if ffile!=None else '_NULL_'
        return (src,url,ffile)
    return None

class Web(object):
    url   = 'http://vobs.magic.pic.es/fits/'
    table = {'class':'mytable'}
    _html = None

    class _HTML(HTMLBase):
        fields = {'Blazar'                       :0,
                  'Publication'                  :1,
                  'VERITAS results page'         :2,
                  'Ascii file with spectral data':3}

        def extract_fields(self):
            """
            """
            def check_header(row,fields):
                """
                """
                cells = row.findAll('td')
                for i,cell in enumerate(cells):
                    txt = cell.find(text=True)
                    txt = txt.strip()
                    if txt in fields.keys():
                        fields[txt] = i
                return all([ v is not None for v in fields.values() ])
                
            def get_doi_url(url):
#                 # The url of the reference ("aurl").
#                 from bs4 import BeautifulSoup as BS
#                 import urllib2
#                 import re
#                 _ads = 'adsabs'
#                 _cds = 'cdsads'
#                 _axv = 'arxiv'
#                 if (_ads in url or _cds in url or _axv in url):
#                     soup = BS(urllib2.urlopen (url))
#                     trs = soup.findAll('tr')
#                     filter(lambda x: 'doi' in x.get_text().lower(), trs)
#                     tr = filter(lambda x: 'doi' in x.get_text().lower(), trs)[0]
#                     doi = tr.get_text()
#                     url = 'http://dx.doi.org/'
#                     url += re.sub('DOI:','',re.sub('\n','',doi))
                return url
    
            _table = {'Object':[], 'URL':[], 'File':[]}
            for i,row in enumerate(self._html.findAll('tr')):
                if i==0:
                    ok = check_header(row,self.fields)
                    if not ok:
                        return None
                    continue
                vals = process_row(row,self.fields.copy())
                if vals is not None:
                    src,url,ffile = vals
                    _table['Object'].append(src)
                    _table['URL'].append(url)
                    _table['File'].append(ffile)
            return _table
            
            
    def __init__(self,url=None):
        if url is not None:
            self.url = url
    
    def __str__(self):
        return str(self.html)

    def get_table(self,table=None, url=None):
        from bs4 import BeautifulSoup as BS
        import urllib2
        if table is not None and isinstance(table,dict):
            self.table = table
        if url is not None:
            self.url = url
        soup = BS(urllib2.urlopen( self.url ).read(),"html.parser")
        table = soup.find('table', self.table )
        self._html = self._HTML(table)

    @property
    def html(self):
        return self._html.html()
    
    def get_table_fields(self):
        return self._html.extract_fields()

# %% [markdown]
# ### Input/Web table

# %%
web = Web()
web.get_table(
    table={'style':"border: 1px solid #000000; height: 587px;",
           'border':"1",
           'width':"669",
           'frame':"vsides",
           'align':"center"
           },
    url='http://veritas.sao.arizona.edu/veritas-science/veritas-blazar-spectra'
)
from IPython.display import HTML
HTML(unicode(web.html))
# Out:
# <table align="center" border="1" frame="vsides" style="border: 1px solid #000000; height: 587px;" width="669">
# <tbody>
# <tr>
# <td><strong>Blazar</strong></td>
# <td><strong>Publication</strong></td>
# <td><strong>VERITAS results page <br/></strong></td>
# <td><strong>Ascii file with spectral data<br/></strong></td>
# </tr>
# <tr>
# <td>1ES0229+200   <br/></td>
# <td><sup>Ap.J. 782, 13 (2014)</sup><br/></td>
# <td><a href="http://veritas.sao.arizona.edu/veritas-science/veritas-results-mainmenu-72/376-1es0229">results</a></td>
# <td><a href="/documents/1ES0229+200_VERITAS_2009_2012_2014ApJ...782...13A.txt">Ascii data</a></td>
# </tr>
# <tr>
# <td>1ES0414+009<br/></td>
# <td><sup>Ap.J. 755, 118 (2012)</sup><br/></td>
# <td><a href="http://veritas.sao.arizona.edu/veritas-science/veritas-results-mainmenu-72/338-1es0414">results</a></td>
# <td><a href="/documents/1ES0414+009_VERITAS_2008-2011_2012ApJ...755..118A.txt">Ascii data</a></td>
# </tr>
# <tr>
# <td>1ES0806+524<br/></td>
# <td><sup>Ap.J. 690, L126 (2009)</sup><br/></td>
# <td><a href="http://veritas.sao.arizona.edu/veritas-science/veritas-results-mainmenu-72/244-1es0806">results</a></td>
# <td><a href="/documents/1ES0806+524_VERITAS_2006-2008_2009ApJ...690L.126A.txt">Ascii data</a></td>
# </tr>
# <tr>
# <td>1ES1215+303<br/></td>
# <td><sup>Ap.J. 779, 92 (2013)</sup><br/></td>
# <td><a href="http://veritas.sao.arizona.edu/veritas-science/veritas-results-mainmenu-72/368-b1215">results</a></td>
# <td><a href="/documents/1ES1215+303_VERITAS_2008-2012_2013ApJ...779...92A.txt">Ascii data</a></td>
# </tr>
# <tr>
# <td>1ES1218+304<br/></td>
# <td><sup>Ap.J. 695, 1370 (2009)</sup><br/></td>
# <td><a href="http://veritas.sao.arizona.edu/veritas-science/veritas-results-mainmenu-72/245-1es1218">results</a></td>
# <td><a href="/documents/1ES1218+304_VERITAS_2007_2009ApJ...695.1370A.txt">Ascii data</a></td>
# </tr>
# <tr>
# <td>1ES1218+304<br/></td>
# <td><sup>Ap.J. 709, L163 (2010)</sup><br/></td>
# <td><a href="http://veritas.sao.arizona.edu/veritas-science/veritas-results-mainmenu-72/236-could-we-put-in-a-journal-reference-here-">results</a></td>
# <td><a href="/documents/1ES1218+304_VERITAS_2008-2009-2010ApJ...709L.163A.txt">Ascii data</a></td>
# </tr>
# <tr>
# <td>1ES1959+650 <br/></td>
# <td><sup>Ap.J. 775, 3 (2013)</sup><br/></td>
# <td><a href="/veritas-science/veritas-results-mainmenu-72/357-1es1959lowflux">results</a></td>
# <td><a href="/documents/1ES1959_VERITAS_2012.txt">Ascii data</a><br/></td>
# </tr>
# <tr>
# <td>1ES2344+514 (high)<br/></td>
# <td><sup>Ap.J. 738, 169 (2011)</sup><br/></td>
# <td><a href="http://veritas.sao.arizona.edu/veritas-science/veritas-results-mainmenu-72/296-1es2344-mwl">results</a></td>
# <td><a href="/documents/1ES2344+514_VERITAS_2007_high_2011ApJ...738..169A.txt">Ascii data</a></td>
# </tr>
# <tr>
# <td>1ES2344+514 (low)<br/></td>
# <td><sup>Ap.J. 738, 169 (2011)</sup><br/></td>
# <td><a href="http://veritas.sao.arizona.edu/veritas-science/veritas-results-mainmenu-72/296-1es2344-mwl">results</a></td>
# <td><a href="/documents/1ES2344+514_VERITAS_2007_low_2011ApJ...738..169A.txt">Ascii data</a></td>
# </tr>
# <tr>
# <td>3C66A (high)<br/></td>
# <td><sup>Ap.J. 693, L104 (2009)</sup><br/></td>
# <td><a href="http://veritas.sao.arizona.edu/veritas-science/veritas-results-mainmenu-72/252-3c66a">results</a></td>
# <td><a href="/documents/3C66A_VERITAS_2007-2008_high_2009ApJ...693L.104A.txt">Ascii data</a></td>
# </tr>
# <tr>
# <td>3C66A (low)<br/></td>
# <td><sup>Ap.J. 693, L104 (2009)</sup><br/></td>
# <td><a href="http://veritas.sao.arizona.edu/veritas-science/veritas-results-mainmenu-72/252-3c66a">results</a></td>
# <td><a href="/documents/3C66A_VERITAS_2007-2008_low_2009ApJ...693L.104A.txt">Ascii data</a></td>
# </tr>
# <tr>
# <td>BLLac<br/></td>
# <td><sup>Ap.J. 762, 92 (2012)</sup><br/></td>
# <td><a href="http://veritas.sao.arizona.edu/veritas-science/veritas-results-mainmenu-72/349-bllac-rapid-flaring">results</a></td>
# <td><a href="/documents/BLLacertae_VERITAS_2011_2013ApJ...762...92A.txt">Ascii data</a></td>
# </tr>
# <tr>
# <td>Mrk 501 (high A)<br/></td>
# <td><sup>Ap.J. 727, 129 (2011)</sup><br/></td>
# <td><a href="http://veritas.sao.arizona.edu/veritas-science/veritas-results-mainmenu-72/269-mrk502-he-emission">results</a></td>
# <td><a href="/documents/Mkn501_VERITAS_2008_highA_2011ApJ...727..129A.txt">Ascii data</a></td>
# </tr>
# <tr>
# <td>Mrk 501 (high B)<br/></td>
# <td><sup>Ap.J. 727, 129 (2011)</sup><br/></td>
# <td><a href="http://veritas.sao.arizona.edu/veritas-science/veritas-results-mainmenu-72/269-mrk502-he-emission">results</a></td>
# <td><a href="/documents/Mkn501_VERITAS_2008_highB_2011ApJ...727..129A.txt">Ascii data</a></td>
# </tr>
# <tr>
# <td>Mrk 501 (high C)<br/></td>
# <td><sup>Ap.J. 727, 129 (2011)</sup><br/></td>
# <td><a href="http://veritas.sao.arizona.edu/veritas-science/veritas-results-mainmenu-72/269-mrk502-he-emission">results</a></td>
# <td><a href="/documents/Mkn501_VERITAS_2008_highC_2011ApJ...727..129A.txt">Ascii data</a></td>
# </tr>
# <tr>
# <td>Mrk 501 (low)<br/></td>
# <td><sup>Ap.J. 727, 129 (2011)</sup><br/></td>
# <td><a href="http://veritas.sao.arizona.edu/veritas-science/veritas-results-mainmenu-72/269-mrk502-he-emission">results</a></td>
# <td><a href="/documents/Mkn501_VERITAS_2008_low_2011ApJ...727..129A.txt">Ascii data</a></td>
# </tr>
# <tr>
# <td>Mrk 501 (mid)<br/></td>
# <td><sup>Ap.J. 727, 129 (2011)</sup><br/></td>
# <td><a href="http://veritas.sao.arizona.edu/veritas-science/veritas-results-mainmenu-72/269-mrk502-he-emission">results</a></td>
# <td><a href="/documents/Mkn501_VERITAS_2008_mid_2011ApJ...727..129A.txt">Ascii data</a></td>
# </tr>
# <tr>
# <td>Mrk 501 (very high)<br/></td>
# <td><sup>Ap.J. 727, 129 (2011)</sup><br/></td>
# <td><a href="http://veritas.sao.arizona.edu/veritas-science/veritas-results-mainmenu-72/269-mrk502-he-emission">results</a></td>
# <td><a href="/documents/Mkn501_VERITAS_2008_veryhigh_2011ApJ...727..129A.txt">Ascii data</a></td>
# </tr>
# <tr>
# <td>Mrk 501 (very low)<br/></td>
# <td><sup>Ap.J. 727, 129 (2011)</sup><br/></td>
# <td><a href="http://veritas.sao.arizona.edu/veritas-science/veritas-results-mainmenu-72/269-mrk502-he-emission">results</a></td>
# <td><a href="/documents/Mkn501_VERITAS_2008_verylow_2011ApJ...727..129A.txt">Ascii data</a></td>
# </tr>
# <tr>
# <td>PG1553+113<br/></td>
# <td><sup> </sup>Ap.J. 799, 7 (2015) <br/></td>
# <td><a href="http://veritas.sao.arizona.edu/veritas-science/veritas-results-mainmenu-72/389-pg1553">results</a></td>
# <td><a href="/documents/PG1553+113_VERITAS_2010-2012_2014arXiv1411.1439A.txt">Ascii data</a></td>
# </tr>
# <tr>
# <td>PKS1424+240<br/></td>
# <td><sup>Ap.J. 785, L16 (2014)</sup><br/></td>
# <td><a href="http://veritas.sao.arizona.edu/veritas-science/veritas-results-mainmenu-72/380-pks1424deep">results</a></td>
# <td><a href="/documents/PKS1424+240_VERITAS_2009_2014ApJ...785L..16A.txt">Ascii data</a></td>
# </tr>
# <tr>
# <td>PKS1424+240<br/></td>
# <td><sup>Ap.J. 785, L16 (2014)</sup><br/></td>
# <td><a href="http://veritas.sao.arizona.edu/veritas-science/veritas-results-mainmenu-72/380-pks1424deep">results</a></td>
# <td><a href="/documents/PKS1424+240_VERITAS_2009_2014ApJ...785L..16A.txt">Ascii data</a></td>
# </tr>
# <tr>
# <td>PKS1424+240<br/></td>
# <td><sup>Ap.J. 785, L16 (2014)</sup><br/></td>
# <td><a href="http://veritas.sao.arizona.edu/veritas-science/veritas-results-mainmenu-72/380-pks1424deep">results</a></td>
# <td><a href="/documents/PKS1424+240_VERITAS_2013_2014ApJ...785L..16A.txt">Ascii data</a></td>
# </tr>
# <tr>
# <td>RBS0413<br/></td>
# <td><sup>Ap.J. 750, 94 (2012)</sup><br/></td>
# <td><a href="http://veritas.sao.arizona.edu/veritas-science/veritas-results-mainmenu-72/318-rbs0413">results</a></td>
# <td><a href="/documents/RBS0413_VERITAS_2008-2009_2012ApJ...750...94A.txt">Ascii data</a></td>
# </tr>
# <tr>
# <td>RGB0710+591<br/></td>
# <td><sup>Ap.J. 715, L49 (2010)</sup><br/></td>
# <td><a href="http://veritas.sao.arizona.edu/veritas-science/veritas-results-mainmenu-72/251-rgbj0710591">results</a></td>
# <td><a href="/documents/RGBJ0710+591_VERITAS_2008-2009_2010ApJ...715L..49A.txt">Ascii data</a></td>
# </tr>
# <tr>
# <td>RXJ0648.7+1516<br/></td>
# <td><sup>Ap.J. 742, 127 (2011)</sup><br/></td>
# <td><a

# %%
f = web.get_table_fields()

# %%
import pandas
class Local(pandas.DataFrame):
    def __init__(self,table):
        super(Local,self).__init__(table)
    
    def describe(self):
        print super(Local,self).describe()
        print "\n-> Has Nil?"
        hows_nil = self.isnull().any()
        print hows_nil
        for c in hows_nil.index:
            if not hows_nil[c]: continue
            print "\n-> Indexes where column '{}' is null:".format(c)
            print self[self[c].isnull()].index.values

# %%
table = Local(f)
table.describe()
print table
# Out:
#                                                      File       Object  \
# count                                                  29           29
# unique                                                 28           26
# top     /documents/PKS1424+240_VERITAS_2009_2014ApJ......  PKS1424+240
# freq                                                    2            3
#
#                                                       URL
# count                                                  29
# unique                                                 19
# top     http://veritas.sao.arizona.edu/veritas-science...
# freq                                                    7
#
# -> Has Nil?
# File      False
# Object    False
# URL       False
# dtype: bool
#                                                  File               Object  \
# 0   /documents/1ES0229+200_VERITAS_2009_2012_2014A...          1ES0229+200
# 1   /documents/1ES0414+009_VERITAS_2008-2011_2012A...          1ES0414+009
# 2   /documents/1ES0806+524_VERITAS_2006-2008_2009A...          1ES0806+524
# 3   /documents/1ES1215+303_VERITAS_2008-2012_2013A...          1ES1215+303
# 4   /documents/1ES1218+304_VERITAS_2007_2009ApJ......          1ES1218+304
# 5   /documents/1ES1218+304_VERITAS_2008-2009-2010A...          1ES1218+304
# 6                 /documents/1ES1959_VERITAS_2012.txt          1ES1959+650
# 7   /documents/1ES2344+514_VERITAS_2007_high_2011A...   1ES2344+514 (high)
# 8   /documents/1ES2344+514_VERITAS_2007_low_2011Ap...    1ES2344+514 (low)
# 9   /documents/3C66A_VERITAS_2007-2008_high_2009Ap...         3C66A (high)
# 10  /documents/3C66A_VERITAS_2007-2008_low_2009ApJ...          3C66A (low)
# 11  /documents/BLLacertae_VERITAS_2011_2013ApJ...7...                BLLac
# 12  /documents/Mkn501_VERITAS_2008_highA_2011ApJ.....     Mrk 501 (high A)
# 13  /documents/Mkn501_VERITAS_2008_highB_2011ApJ.....     Mrk 501 (high B)
# 14  /documents/Mkn501_VERITAS_2008_highC_2011ApJ.....     Mrk 501 (high C)
# 15  /documents/Mkn501_VERITAS_2008_low_2011ApJ...7...        Mrk 501 (low)
# 16  /documents/Mkn501_VERITAS_2008_mid_2011ApJ...7...        Mrk 501 (mid)
# 17  /documents/Mkn501_VERITAS_2008_veryhigh_2011Ap...  Mrk 501 (very high)
# 18  /documents/Mkn501_VERITAS_2008_verylow_2011ApJ...   Mrk 501 (very low)
# 19  /documents/PG1553+113_VERITAS_2010-2012_2014ar...           PG1553+113
# 20  /documents/PKS1424+240_VERITAS_2009_2014ApJ......          PKS1424+240
# 21  /documents/PKS1424+240_VERITAS_2009_2014ApJ......          PKS1424+240
# 22  /documents/PKS1424+240_VERITAS_2013_2014ApJ......          PKS1424+240
# 23  /documents/RBS0413_VERITAS_2008-2009_2012ApJ.....              RBS0413
# 24  /documents/RGBJ0710+591_VERITAS_2008-2009_2010...          RGB0710+591
# 25  /documents/RXJ0648.7+1516_VERITAS_2010_2011ApJ...       RXJ0648.7+1516
# 26  /documents/VERJ0521+211_VERITAS_2009-2010_2013...          VER0521+211
# 27  /documents/WComae_VERITAS_2008-01-04_2008ApJ.....               WComae
# 28    /documents/Mrk421_VERITAS_2011ApJ...738..25.txt              Mrk 421
#
#                                                   URL
# 0   http://veritas.sao.arizona.edu/veritas-science...
# 1   http://veritas.sao.arizona.edu/veritas-science...
# 2   http://veritas.sao.arizona.edu/veritas-science...
# 3   http://veritas.sao.arizona.edu/veritas-science...
# 4   http://veritas.sao.arizona.edu/veritas-science...
# 5   http://veritas.sao.arizona.edu/veritas-science...
# 6   /veritas-science/veritas-results-mainmenu-72/3...
# 7   http://veritas.sao.arizona.edu/veritas-science...
# 8   http://veritas.sao.arizona.edu/veritas-science...
# 9   http://veritas.sao.arizona.edu/veritas-science...
# 10  http://veritas.sao.arizona.edu/veritas-science...
# 11  http://veritas.sao.arizona.edu/veritas-science...
# 12  http://veritas.sao.arizona.edu/veritas-science...
# 13  http://veritas.sao.arizona.edu/veritas-science...
# 14  http://veritas.sao.arizona.edu/veritas-science...
# 15  http://veritas.sao.arizona.edu/veritas-science...
# 16  http://veritas.sao.arizona.edu/veritas-science...
# 17  http://veritas.sao.arizona.edu/veritas-science...
# 18  http://veritas.sao.arizona.edu/veritas-science...
# 19  http://veritas.sao.arizona.edu/veritas-science...
# 20  http://veritas.sao.arizona.edu/veritas-science...
# 21  http://veritas.sao.arizona.edu/veritas-science...
# 22  http://veritas.sao.arizona.edu/veritas-science...
# 23  http://veritas.sao.arizona.edu/veritas-science...
# 24  http://veritas.sao.arizona.edu/veritas-science...
# 25  http://veritas.sao.arizona.edu/veritas-science...
# 26  http://veritas.sao.arizona.edu/veritas-science...
# 27  http://veritas.sao.arizona.edu/veritas-science...
# 28  http://veritas.sao.arizona.edu/veritas-science...

# %%
def clean_dir(_dir,ext):
    import os
    from glob import glob
    if not os.path.exists(_dir):
        os.mkdir(_dir)
    if os.path.isdir(_dir):
        files = glob(os.path.join(_dir,ext))
        for f in files:
            os.remove(f)

class Download(object):
    def __init__(self,outdir,clean=True):
        import os
        self._outdir = outdir
        if clean:
            self.clean_outdir()
        self._md5 = os.path.join(self._outdir,'md5sum')
        
    def download(self,url):
        import wget
        filename = wget.download(url,out=self._outdir)
        return filename

    def clean_outdir(self,ext="*"):
        _dir = self._outdir
        clean_dir(_dir,ext)
                

    def create_md5sum_file(self,files_list,_dir=None):
        import hashlib
        md5txt = os.path.join(_dir,self._md5) if _dir else self._md5
        md5 = {}
        for f in files_list:
#             fname = os.path.join(_dir,f) if _dir else f
            fname = f
            h = None
            with open(fname,'rb') as fp:
                h = hashlib.md5(fp.read()).hexdigest()
            md5.update({f:h})
        with open(md5txt,'w') as fp:
            for _file,_hash in md5.iteritems():
                fp.write("%s    %s\n"%(_hash,_file))
        return md5

    def is_exist_files(self,files_list,_dir=None):
        import os
        if _dir is None:
            _dir = self._outdir
        md5_file = self._md5
        
        # First we see if there is a file list (md5sum) to look for
        def check_md5sum(files_list,md5_file):
            if os.path.isfile(md5_file):
                md5 = read_md5sum_file(md5_file)
                md5_files_list = md5.keys()
                leng_inters = len(set(md5_files_list).intersection(files_list))
                return leng_inters == len(files_list)
            # If there is *no* md5-file, return *None*
            return None

        # Also, check if the files are actually there (inside the dir)
        def check_glob(files_list,_dir):
            files_ext = '*.txt'
            dir_files_list = read_dir_content(_dir,files_ext)
            leng_matches = sum(map(lambda v: v in dir_files_list, files_list))
            return leng_matches == len(files_list)

        md5_check = check_md5sum(files_list,md5_file)
        if md5_check in (True,False):
            return md5_check
        glob_check = check_glob(files_list,_dir)
        if glob_check:
            self.create_md5sum_file(files_list,_dir=_dir)
        return glob_check

def read_dir_content(_dir,ext='*'):
    from glob import glob
    dir_files_list = glob(os.path.join(_dir,ext))
    return [ os.path.basename(f) for f in dir_files_list ]

def read_md5sum_file(md5txt):
    import os
    assert os.path.isfile(md5txt)

    md5_hashs,md5_files = [],[]
    with open(md5txt,'r') as mdf:
        for line in mdf.readlines():
            _h,_f = line.split()
            md5_hashs.append(_h.strip())
            md5_files.append(_f.strip())
    md5 = dict(zip(md5_files,md5_hashs))
    return md5

# %%
download_dir = 'data/'
download_handler = Download(download_dir,clean=True)

# %%
import os

_files = table['File'].dropna().apply(os.path.basename)
if download_handler.is_exist_files(_files):
    print("FITS files exist locally. Passing by download step..")
    _files = _files.apply(lambda f: os.path.join(download_dir,f))
else:
    print("FITS files do not exist locally. Downloading them...")
    furls = web.url + table['File'].dropna()
    _files = furls.apply(lambda f: download_handler.download(f))
    print _files
    md5s = download_handler.create_md5sum_file(_files)
    del furls

table['File'] = _files
# Out:
# FITS files do not exist locally. Downloading them...
# 0     data//1ES0229+200_VERITAS_2009_2012_2014ApJ......
# 1     data//1ES0414+009_VERITAS_2008-2011_2012ApJ......
# 2     data//1ES0806+524_VERITAS_2006-2008_2009ApJ......
# 3     data//1ES1215+303_VERITAS_2008-2012_2013ApJ......
# 4     data//1ES1218+304_VERITAS_2007_2009ApJ...695.1...
# 5     data//1ES1218+304_VERITAS_2008-2009-2010ApJ......
# 6                        data//1ES1959_VERITAS_2012.txt
# 7     data//1ES2344+514_VERITAS_2007_high_2011ApJ......
# 8     data//1ES2344+514_VERITAS_2007_low_2011ApJ...7...
# 9     data//3C66A_VERITAS_2007-2008_high_2009ApJ...6...
# 10    data//3C66A_VERITAS_2007-2008_low_2009ApJ...69...
# 11    data//BLLacertae_VERITAS_2011_2013ApJ...762......
# 12    data//Mkn501_VERITAS_2008_highA_2011ApJ...727....
# 13    data//Mkn501_VERITAS_2008_highB_2011ApJ...727....
# 14    data//Mkn501_VERITAS_2008_highC_2011ApJ...727....
# 15    data//Mkn501_VERITAS_2008_low_2011ApJ...727..1...
# 16    data//Mkn501_VERITAS_2008_mid_2011ApJ...727..1...
# 17    data//Mkn501_VERITAS_2008_veryhigh_2011ApJ...7...
# 18    data//Mkn501_VERITAS_2008_verylow_2011ApJ...72...
# 19    data//PG1553+113_VERITAS_2010-2012_2014arXiv14...
# 20    data//PKS1424+240_VERITAS_2009_2014ApJ...785L....
# 21    data//PKS1424+240_VERITAS_2009_2014ApJ...785L....
# 22    data//PKS1424+240_VERITAS_2013_2014ApJ...785L....
# 23    data//RBS0413_VERITAS_2008-2009_2012ApJ...750....
# 24    data//RGBJ0710+591_VERITAS_2008-2009_2010ApJ.....
# 25    data//RXJ0648.7+1516_VERITAS_2010_2011ApJ...74...
# 26    data//VERJ0521+211_VERITAS_2009-2010_2013ApJ.....
# 27    data//WComae_VERITAS_2008-01-04_2008ApJ...684L...
# 28           data//Mrk421_VERITAS_2011ApJ...738..25.txt
# Name: File, dtype: object

# %%
print table
# Out:
#                                                  File               Object  \
# 0   data//1ES0229+200_VERITAS_2009_2012_2014ApJ......          1ES0229+200
# 1   data//1ES0414+009_VERITAS_2008-2011_2012ApJ......          1ES0414+009
# 2   data//1ES0806+524_VERITAS_2006-2008_2009ApJ......          1ES0806+524
# 3   data//1ES1215+303_VERITAS_2008-2012_2013ApJ......          1ES1215+303
# 4   data//1ES1218+304_VERITAS_2007_2009ApJ...695.1...          1ES1218+304
# 5   data//1ES1218+304_VERITAS_2008-2009-2010ApJ......          1ES1218+304
# 6                      data//1ES1959_VERITAS_2012.txt          1ES1959+650
# 7   data//1ES2344+514_VERITAS_2007_high_2011ApJ......   1ES2344+514 (high)
# 8   data//1ES2344+514_VERITAS_2007_low_2011ApJ...7...    1ES2344+514 (low)
# 9   data//3C66A_VERITAS_2007-2008_high_2009ApJ...6...         3C66A (high)
# 10  data//3C66A_VERITAS_2007-2008_low_2009ApJ...69...          3C66A (low)
# 11  data//BLLacertae_VERITAS_2011_2013ApJ...762......                BLLac
# 12  data//Mkn501_VERITAS_2008_highA_2011ApJ...727....     Mrk 501 (high A)
# 13  data//Mkn501_VERITAS_2008_highB_2011ApJ...727....     Mrk 501 (high B)
# 14  data//Mkn501_VERITAS_2008_highC_2011ApJ...727....     Mrk 501 (high C)
# 15  data//Mkn501_VERITAS_2008_low_2011ApJ...727..1...        Mrk 501 (low)
# 16  data//Mkn501_VERITAS_2008_mid_2011ApJ...727..1...        Mrk 501 (mid)
# 17  data//Mkn501_VERITAS_2008_veryhigh_2011ApJ...7...  Mrk 501 (very high)
# 18  data//Mkn501_VERITAS_2008_verylow_2011ApJ...72...   Mrk 501 (very low)
# 19  data//PG1553+113_VERITAS_2010-2012_2014arXiv14...           PG1553+113
# 20  data//PKS1424+240_VERITAS_2009_2014ApJ...785L....          PKS1424+240
# 21  data//PKS1424+240_VERITAS_2009_2014ApJ...785L....          PKS1424+240
# 22  data//PKS1424+240_VERITAS_2013_2014ApJ...785L....          PKS1424+240
# 23  data//RBS0413_VERITAS_2008-2009_2012ApJ...750....              RBS0413
# 24  data//RGBJ0710+591_VERITAS_2008-2009_2010ApJ.....          RGB0710+591
# 25  data//RXJ0648.7+1516_VERITAS_2010_2011ApJ...74...       RXJ0648.7+1516
# 26  data//VERJ0521+211_VERITAS_2009-2010_2013ApJ.....          VER0521+211
# 27  data//WComae_VERITAS_2008-01-04_2008ApJ...684L...               WComae
# 28         data//Mrk421_VERITAS_2011ApJ...738..25.txt              Mrk 421
#
#                                                   URL
# 0   http://veritas.sao.arizona.edu/veritas-science...
# 1   http://veritas.sao.arizona.edu/veritas-science...
# 2   http://veritas.sao.arizona.edu/veritas-science...
# 3   http://veritas.sao.arizona.edu/veritas-science...
# 4   http://veritas.sao.arizona.edu/veritas-science...
# 5   http://veritas.sao.arizona.edu/veritas-science...
# 6   /veritas-science/veritas-results-mainmenu-72/3...
# 7   http://veritas.sao.arizona.edu/veritas-science...
# 8   http://veritas.sao.arizona.edu/veritas-science...
# 9   http://veritas.sao.arizona.edu/veritas-science...
# 10  http://veritas.sao.arizona.edu/veritas-science...
# 11  http://veritas.sao.arizona.edu/veritas-science...
# 12  http://veritas.sao.arizona.edu/veritas-science...
# 13  http://veritas.sao.arizona.edu/veritas-science...
# 14  http://veritas.sao.arizona.edu/veritas-science...
# 15  http://veritas.sao.arizona.edu/veritas-science...
# 16  http://veritas.sao.arizona.edu/veritas-science...
# 17  http://veritas.sao.arizona.edu/veritas-science...
# 18  http://veritas.sao.arizona.edu/veritas-science...
# 19  http://veritas.sao.arizona.edu/veritas-science...
# 20  http://veritas.sao.arizona.edu/veritas-science...
# 21  http://veritas.sao.arizona.edu/veritas-science...
# 22  http://veritas.sao.arizona.edu/veritas-science...
# 23  http://veritas.sao.arizona.edu/veritas-science...
# 24  http://veritas.sao.arizona.edu/veritas-science...
# 25  http://veritas.sao.arizona.edu/veritas-science...
# 26  http://veritas.sao.arizona.edu/veritas-science...
# 27  http://veritas.sao.arizona.edu/veritas-science...
# 28  http://veritas.sao.arizona.edu/veritas-science...

# %% [markdown]
# #### Header keywords
#  Primarily, regarding particularly MAGIC data, we should take a look at their [FITS format for MAGIC data](http://vobs.magic.pic.es/fits/mfits/tdas/tdas-fits.pdf) document, chapter 4. There we'll find the following list of keywords:
#
# __FITS standard__, _highlighted by MAGIC_:
#  * AUTHOR
#  * DATE
#  * DATE-OBS
#  * EXTNAME
#  * OBJECT
#  * ORIGIN
#  * TELESCOP
#
# __MAGIC__, _to describe extension content_:
#  * CONFLEVE
#  * EFFICIEN
#  * EMAX
#  * EMIN
#  * PERIOD
#  * PHIMAX
#  * PHIMIN
#  * REFPAPER
#  * SIZEMIN
#  * SIZEMAX
#  * TOBS
#  * ZMIN
#  * ZMAX
#  * TZERO
#  * VERSION
#
# __MAGIC__, _SPECTRUM extension_:
#  * ISINTEGR : 'F' means density flux; 'I' means integrated flux.
#
# On the other hand, there is the [FITS standard](http://heasarc.gsfc.nasa.gov/docs/fcg/standard_dict.html) and the [FITS commons](http://heasarc.gsfc.nasa.gov/docs/fcg/common_dict.html) set of keywords.
#
#
# ```
# This data dictionary lists the 53 keywords currently defined in the
# FITS Standard:
#
# (blank)  CROTAn   EQUINOX  NAXISn   TBCOLn   TUNITn
# AUTHOR   CRPIXn   EXTEND   OBJECT   TDIMn    TZEROn
# BITPIX   CRVALn   EXTLEVEL OBSERVER TDISPn   XTENSION
# BLANK    CTYPEn   EXTNAME  ORIGIN   TELESCOP
# BLOCKED  DATAMAX  EXTVER   PCOUNT   TFIELDS
# BSCALE   DATAMIN  GCOUNT   PSCALn   TFORMn
# BUNIT    DATE     GROUPS   PTYPEn   THEAP
# BZERO    DATE-OBS HISTORY  PZEROn   TNULLn
# CDELTn   END      INSTRUME REFERENC TSCALn
# COMMENT  EPOCH    NAXIS    SIMPLE   TTYPEn
# ```
#
# ```
#      Dictionary of Commonly Used FITS Keywords
#
# This data dictionary contains FITS keywords that have been widely used
# within the astronomical community.  It is recommended that these
# keywords only be used as defined here.  These keywords may be grouped
# within the following 7 broad categories:
#
# 1. Keywords that describe the data or the FITS file itself:
#
#     TITLE FILENAME FILETYPE ROOTNAME
#     PROGRAM CREATOR CONFIGUR
#     NEXTEND HDUNAME HDUVER HDULEVEL
#     TLMINn TLMAXn TDMINn TDMAXn TDBINn
#     TSORTKEY PROGRAM CREATOR CONFIGUR
#     HDUCLASS HDUDOC HDUVERS HDUCLASn
#
# 2.  Keywords that describe the observation:
#
#     SUNANGLE MOONANGL
#     RA DEC RA_NOM DEC_NOM
#     RA_OBJ DEC_OBJ RA_PNT DEC_PNT PA_PNT
#     RA_SCX DEC_SCX RA_SCY DEC_SXY RA_SCZ DEC_SCZ
#     ORIENTAT AIRMASS LATITUDE
#     OBJNAME OBS_ID
#
# 3.  Keywords that describe the instrument that took the data:
#
#     OBS_MODE DATAMODE
#     APERTURE DETNAM FILTER FILTERn GRATING GRATINGn
#     SATURATE
#
# 4.  Keywords that give the date or duration of the observation:
#
#     TIME-OBS TIME-END DATE-END
#     EXPOSURE EXPTIME TELAPSE ELAPTIME ONTIME LIVETIME
#
# 5.  Keywords that denote non-standard FITS keyword format conventions:
#
#     HIERARCH INHERIT CONTINUE
#
# 6.  File checksum keywords:
#
#     CHECKSUM DATASUM CHECKVER
#
# 7.  Hierarchical file grouping keywords:
#
#     GRPNAME GRPIDn GRPLCn
# ```
#
# ---
#
# #### Improvement
#
#  * Given all those lists of keywords, I will just add `RA` and `DEC`.

# %%
# The following keywords may not be seen in the Extended BinTableHDU header, but inside the PrimaryHDU' header.
# That's because the MAGIC data handling system decided to not repeat unnecessarily such data.
# See the 'General Keywords' section (4.1) of the document 'FITS Format for MAGIC data', version 0.2.
#
MAGIC_FITS_STANDARD_KEYWORDS = [
    'AUTHOR',
    'DATE',
    'DATE-OBS',
    'EXTNAME',
    'OBJECT',
    'ORIGIN',
    'TELESCOP']
MAGIC_FITS_EXTENSION_KEYWORDS = [
    'CONFLEVE',
    'EFFICIEN',
    'EMAX',
    'EMIN',
    'PERIOD',
    'PHIMAX',
    'PHIMIN',
    'REFPAPER',
    'SIZEMIN',
    'SIZEMAX',
    'TOBS',
    'ZMIN',
    'ZMAX',
    'TZERO',
    'VERSION']
# These keywords will be used to update the SPECTRUM extensions with *all* of them
FITS_KEYWORDS = MAGIC_FITS_STANDARD_KEYWORDS + MAGIC_FITS_EXTENSION_KEYWORDS

# %%
# Now we can process the fits files themselves.
# He start noting that we want the SPECTRUM Data Unit(s)
#  available (or not) in the fits files; discard the other DU.
# Things we want to do:
# - get the OBJECT name
# - get the each object position
# - get the observation date
# - transform the data vectors (x) to frequency(Hz) and (y) to flux(erg/s/cm2)
# Then we should follow the following workflow:
# - open the fits file
# - find the necessary data unit (SPECTRUM)
# - open its header
#  - get some keywords from the header
# - open its data; data here are vectors
#  - it can be from 2 to 4 vectors
#   - energy
#   - flux
#   - Denergy
#   - Dflux
#  - convert the ?energy vectors to 'Hz' units
#  - convert the ?flux vectors to 'erg/s/cm2' units

# Here we just define the functions we'll need..
def resolve_name(name):
    from astropy.coordinates import get_icrs_coordinates as get_coords
    try:
        icrs = get_coords(name)
        pos = (icrs.ra.value,icrs.dec.value)
    except:
        pos = None
    return pos

def fix_dateobs(date):
    try:
        dt = str(date).split('-')
        y = int(dt[0])
    except:
        return '1999-01-01'
    try:
        m = int(dt[1])
    except:
        m = 1
    try:
        d = int(dt[2])
    except:
        d = 1
    return '{:4d}-{:02d}-{:02d}'.format(y,m,d)

def merge_header_keywords(header_p,header_s):
    # Extension's header has the highest priority; keywords there
    # should not be overwritten. Relevant keywords are the ones in:
    # 'FITS_KEYWORDS'
    f_header = {'COMMENT':[]}
    _kw = list(set(header_p.keys()).intersection(FITS_KEYWORDS))
    for k in _kw:
        f_header.update({k : header_p[k]})
    if 'COMMENT' in header_p.keys():
        f_header['COMMENT'].extend(header_p['COMMENT'])
    _kw = list(set(header_s.keys()).intersection(FITS_KEYWORDS))
    for k in _kw:
        f_header.update({k : header_s[k]})
    if 'COMMENT' in header_s.keys():
        f_header['COMMENT'].extend(header_s['COMMENT'])
    return f_header
    
def trans_data(table):
    import numpy as np
    from astropy import units
    Unit = units.Unit
    
    units.set_enabled_equivalencies(units.spectral())
    uEn = Unit('Hz')
    uFn = Unit('erg s-1 cm-2')
    uEc = Unit('TeV')
    conv = {Unit('ph TeV s-1 cm-2') : lambda x,y: (x/Unit('ph')).to(uFn),
            Unit('ph TeV-1 s-1 cm-2') : lambda x,y: ((y.to(uEc)**2)*(x/Unit('ph'))).to(uFn),
            Unit('ph s-1 cm-2') : lambda x,y: None,
            Unit('GeV') : lambda x: x.to(uEn, equivalencies=units.spectral())}

    vE = table['energy']
    uE = vE.unit
    vEn = conv[uE](vE)

    vF = table['flux']
    uF = vF.unit
    vFn = conv[uF](vF,vE)

    if vFn is None:
        print("Flux data could not be transformed. Unrecognised units ({})?".format(uF.to_string()))
        return False

    def set_null(column,null_expression,new_null_value=-999):
        _idx = np.where(null_expression(column))
        column[_idx] = new_null_value
        column.null = new_null_value
        
    nullval = -999
    new_nullval = nullval
    
    table['energy'] = vEn
    table['energy'].unit = vEn.unit
    set_null( table['energy'], lambda x:x==0.0)
    table['flux'] = vFn
    table['flux'].unit = vFn.unit
    set_null( table['flux'], lambda x:x==0.0)
    set_null( table['flux'], lambda x:x>0.001)

    if 'Denergy' in table.colnames:
        vDE = table['Denergy']
        uDE = vDE.unit
        vDEn = conv[uDE](vDE)
        table['energy_error'] = vDEn
        table['energy_error'].unit = vDEn.unit
        set_null( table['energy_error'], lambda x:x==0.0)
        del table['Denergy']
    else:
        uDE = table['energy'].unit
        vDEn = np.asarray([nullval]*len(vE),dtype=int)
        table['energy_error'] = vDEn
        table['energy_error'].unit = uDE
        table['energy_error'].null = nullval

    if 'Dflux' in table.colnames:
        vDF = table['Dflux']
        uDF = vDF.unit
        vDFn = conv[uDF](vDF,vE) # Notice we use the energy bin/value of the measurement.
        table['flux_error'] = vDFn
        table['flux_error'].unit = vDFn.unit
        set_null( table['flux_error'], lambda x:x==0.0)
        del table['Dflux']
    else:
        uDF = table['flux'].unit
        vDFn = np.asarray([nullval]*len(vE),dtype=int)
        table['flux_error'] = vDFn
        table['flux_error'].unit = uDF
        table['flux_error'].null = nullval

    return True

# def header_to_dict(header):
#     from collections import OrderedDict
#     out = OrderedDict()
#     for card in header.cards:
#         k = card[0]
#         v = card[1]
#         c = card[2]
#         out[k] = v   # 'c' is out for the time being
#     return out

# %%
class SourceFits(object):
    """
    """
    def __init__(self,source_name,filename):
        self._source = source_name
        self._file = Fits(filename)
        self._spectra = []

    def __len__(self):
        return len(self._spectra)
    
    def __nonzero__(self):
        return bool(self._file)
    
    def hasSpectra(self):
        if not self._file.isValid():
            return False
        return self._file.hasSpectrum()

    def loadSpectra(self):
        if self.hasSpectra():
            self._spectra = self._file.get_spectra()
        else:
            assert len(self._spectra)==0
            
    def getSpectra(self):
        if not self._spectra:
            self.loadSpectra()
        return self._spectra

    
class Fits(object):
    """
    Handles the file's infomation set
    """
    _file = None
    _hdulist = None
    _specHDU = 'SPECTRUM'

    def __init__(self, filename):
        self._file = filename
        self.read_file()

    def __nonzero__(self):
        return self._file != None and self._hdulist != None
    
    @property
    def name(self):
        return self._file

    @property
    def header(self):
        return self._hdulist[0].header

    def read_file(self):
        from astropy.io import fits
        filename = self._file
        try:
            hdulist = fits.open(filename)
        except:
            hdulist = None
        self._hdulist = hdulist

    def isValid(self):
        return self._hdulist != None

    def hasSpectrum(self):
        duname = self._specHDU
        if not self.isValid():
            return None
        return any([ duname in du.name for du in self._hdulist ])

    def get_spectra(self):
        duname = self._specHDU
        if not self.hasSpectrum():
            return None
        hdulist = self._hdulist
        dui = [ i for i,du in enumerate(hdulist) if duname in du.name ]
        dus = [ Spectrum(self,hdu=ii) for ii in dui ]
        return dus

    def get_hdu(self,hdu):
        if not self.isValid():
            return None
        return self._hdulist[hdu]

    
HEADERS_TMP = []

class Spectrum(object):
    """
    Handles fits Spectrum HDU
    """
    def __init__(self,fits,hdu):
        assert isinstance(fits,Fits)
        self._hdu = fits.get_hdu(hdu)
        self._file = fits
        self._i = hdu
        self._table = None
        self._meta = None
#         self._fileout = None
        
    def __len__(self):
        return len(self._table) if self else 0
    
    def __nonzero__(self):
        return True if self._table else False
    
    def __str__(self):
        return str(self._table)
    
    @property
    def label(self):
        return self.header['EXTNAME']

    @property
    def header(self):
        return self._hdu.header

    def upgrade_metadata(self, metadata):
        phdu_header = self._file.header
        shdu_header = self.header
        header = merge_header_keywords(phdu_header,shdu_header)
        assert isinstance(header,dict)
        
        def check_header_for_EBL(header):
            def blue(string):
                return '\033[96m {}\033[00m'.format(string)
            def red(string):
                return '\033[91m {}\033[00m'.format(string)

            ebl_occ = []
            for k,v in header.iteritems():
                v = str(v)
                ebl = bool('ebl' in v.lower().rstrip())
                if ebl:
                    ebl_occ.append( (k,v) )
            if bool(len(ebl_occ)):
                _str = blue('True')
            else:
                _str = red('False')
            print "\nIs EBL-correted? {}".format( _str )
            return ebl_occ

        occs = check_header_for_EBL(header)
        header['EBL_CORR'] = 'TRUE' if occs else 'FALSE'

        if not 'OBJECT' in header.keys():
            header['OBJECT'] = None
            print "\n'OBJECT' keyword not defined."
            return False
            
        pos = resolve_name(header['OBJECT'])
        if pos is None:
            print "\nObject position not defined, (RA,DEC) unresolved."
            return False
            #pos = resolve_name(source)
            #if pos is None:
            #    pos = (None,None)

        header['RA'],header['DEC'] = pos
        print "\nResolved position (through Simbad): ",pos
        
        if ('SRCPOS1' in header.keys()) and ('SRCPOS2' in header.keys()):
            pos = header['SRCPOS1'],header['SRCPOS2']
        elif ('SRCPOS1' in phdu_header.keys()) and ('SRCPOS2' in phdu_header.keys()):
            pos = phdu_header['SRCPOS1'],phdu_header['SRCPOS2']
        else:
            pos = (None,None)
            
        header['SRCPOS1'],header['SRCPOS2'] = pos
        print "Found position on fits header: ",pos
        
        try:
            header['DATE-OBS'] = fix_dateobs(header['DATE-OBS'])
        except:
            header['DATE-OBS'] = fix_dateobs(None)

        for k,v in metadata.iteritems():
            _key = k.upper()
            _value = v
            header[_key] = _value

        HEADERS_TMP.append(header.copy())
        self._meta = header
        return True

    def transform_data(self):
        from astropy import units
        Unit = units.Unit
        import numpy as np

        # Read the extension directly into an astropy.table
        from astropy.table import Table
        fn = self._file.name
        i_du = self._i
        table = Table.read(fn,hdu=i_du)
        res = trans_data(table)
        if res:
            self._table = table

    def retrieve_table(self):
        if not self._table:
            return None
        table = self._table
        header = self._meta
        table.meta.update(header)
        return table.copy()

    def suggest_output_filename(self,output_dir=None):
        def fix_filename(table,filename,odir):
            import os,re
            filename = os.path.basename(filename)
            filename = re.sub('[+]','p',filename)
            extname = '_' + table.meta['EXTNAME'] + '.fits'
            fitsfilename = os.path.join(odir,re.sub('.fits',extname,filename))
            return fitsfilename
        filename = self._file.name
        table = self._table
        odir = output_dir if output_dir is not None else './'
        return fix_filename(table,filename,odir)
    
    def dropna(self, columns, na_value, rows=True):
        assert rows==True
        from numpy import where
        table = self._table
        idx = set()
        for c in columns:
            _idx = where(table[c] == na_value)[0]
            idx = idx.union(set(_idx.tolist()))
        idx = list(idx)
        table.remove_rows(idx)
        return idx

    
def write_to_fits(spectrum, output_dir=None, votable=False):
    def write_table(table,filename,votable):
        table.write(filename,format='fits')
        if votable:
            votfilename = filename[:-5] + '.vot'
            table.write(votfilename,format='votable')
        return filename
    table = spectrum.retrieve_table()
    filename = spectrum.suggest_output_filename(output_dir)
    return write_table(table,filename,votable)

# %%
def proc_fits_file(fn,source,url_article):
    """
    Returns a (plain) list with all valid spectra in it.
    """
    
    print "\n======================================================================"
    print "Taking file: ",fn
    print "Source name: ",source
    print "Article: ",url_article

    src = SourceFits(source,fn)
    
    if not src:
        eprint("***: File opening failed. Moving on.")
        return None
    
    if not src.hasSpectra():
        eprint("***: File has no SPECTRUM data-unit in it.")
        return None
        
    spectra = src.getSpectra()
    assert len(spectra) > 0
    
    out = []
    for spec in spectra:
        print "\n----------------------------------------------------------------------"
        print "\nProcessing spectrum (DataUnit): ",spec.label

        res = spec.upgrade_metadata(metadata = {'refurl':url_article})
        if not res:
            eprint("***: Metadata (Headers) verification failed. Continue to next spectrum.")
            continue
        
        spec.transform_data()
        
        print
        print spec
        if not spec:
            eprint("***: Spectrum data could not be properly transofrmed. Continue to next spectrum.")
            continue
            
        del_rows = spec.dropna(columns=['energy','flux'],na_value=-999)
        if del_rows:
            print "\n{} rows eliminated from table: {}.".format(len(del_rows),del_rows)
            if len(spec)==0:
                eprint("***: Table is empty; not to be writen. Continue to next spectrum.")
                continue
        print "\nOutput filename: {}".format(spec.suggest_output_filename(output_dir=''))
        print "**********************************************************************"
        out.append(spec)
        
    return out

# %% [markdown]
# ### Files processing logfile

# %%
table['SPECTRUM'] = table.apply(lambda x: proc_fits_file(x.FITS,x.SOURCE,x.URL), axis=1)
# Out:
# ======================================================================
# Taking file:  nan
# Source name:  Mrk 421
# Article:  http://cdsads.u-strasbg.fr/abs/2014arXiv1412.3576T
#
# ERROR:***: File opening failed. Moving on.
#
# ======================================================================
# Taking file:  FITS_pic/MAGIC_2015_CrabNebula.fits
# Source name:  Crab Nebula
# Article:  http://cdsads.u-strasbg.fr/abs/2014arXiv1406.6892M
#
# ----------------------------------------------------------------------
#
# Processing spectrum (DataUnit):  SPECTRUM
#
# Is EBL-correted?  False
#
# Resolved position (through Simbad):  (83.633083, 22.0145)
# Found position on fits header:  (None, None)
#
#       energy             flux       energy_error     flux_error
#         Hz          erg / (cm2 s)        Hz        erg / (cm2 s)
# ----------------- ----------------- ------------ -----------------
# 1.56025356963e+25 3.62805869585e-13         -999 1.13904928544e-15
# 2.50087802451e+25 9.43132530586e-13         -999  1.9694134259e-15
# 3.94770613174e+25  2.3715794771e-12         -999 4.13655965554e-14
#  6.1126770758e+25 5.03369606776e-12         -999 8.14063738269e-14
# 9.51868105355e+25 1.16224204472e-11         -999 1.84607595297e-13
#  1.4848630797e+26 2.31956872225e-11         -999  3.8266271044e-13
# 2.31731878102e+26 4.88346500098e-11         -999 9.62385180571e-13
# 3.61806164371e+26 9.95830696063e-11         -999 2.48577432619e-12
# 5.64893089844e+26 1.76945485666e-10         -999 6.55280067411e-12
# 8.82367837479e+26 3.27814272776e-10         -999 1.85672452589e-11
# 1.37826118324e+27 4.50879797152e-10         -999 4.33892082121e-11
# 2.15188720369e+27   9.382709776e-10         -999 1.11834986337e-10
# 3.36124699489e+27 1.39311196273e-09         -999 2.56627712888e-10
# 5.25027699437e+27 1.46358840265e-09         -999 6.70351513049e-10
#
# Output filename: MAGIC_2015_CrabNebula_SPECTRUM.fits
# **********************************************************************
#
# ----------------------------------------------------------------------
#
# Processing spectrum (DataUnit):  SPECTRUM_1
#
# Is EBL-correted?  False
#
# Resolved position (through Simbad):  (83.633083, 22.0145)
# Found position on fits header:  (None, None)
#
#       energy             flux       energy_error     flux_error
#         Hz          erg / (cm2 s)        Hz        erg / (cm2 s)
# ----------------- ----------------- ------------ -----------------
# 1

#
#       energy             flux       energy_error     flux_error
#         Hz          erg / (cm2 s)        Hz        erg / (cm2 s)
# ----------------- ----------------- ------------ -----------------
# 4.40855072188e+25 1.23209983687e-11         -999 9.10447222121e-12
# 8.51156430954e+25 5.39482231092e-12         -999 4.11892664416e-12
# 1.64332601173e+26 3.90625342702e-12         -999 2.18508527861e-12
# 3.17276472508e+26 2.51876472037e-12         -999 2.45911155951e-12
#
# Output filename: MAGIC_2006_Mrk180_SPECTRUM_1.fits
# **********************************************************************
#
# ======================================================================
# Taking file:  FITS_pic/MAGIC_2006_LSI61303.fits
# Source name:  LS I +61 303
# Article:  http://adsabs.harvard.edu/cgi-bin/bib_query?arXiv:astro-ph/0605549
#
# ----------------------------------------------------------------------
#
# Processing spectrum (DataUnit):  SPECTRUM
#
# Is EBL-correted?  False
#
# Resolved position (through Simbad):  (40.131938163, 61.229336515)
# Found position on fits header:  (2.67556, 61.229)
#
#       energy             flux       energy_error     flux_error
#         Hz          erg / (cm2 s)        Hz        erg / (cm2 s)
# ----------------- ----------------- ------------ -----------------
# 5.25436339637e+25 1.56117109465e-11         -999  7.7155981888e-12
# 8.65645023137e+25 1.02042858195e-11         -999 3.18032140725e-12
# 1.42613253639e+26 5.14493645243e-12         -999 1.79736503839e-12
# 2.34952398117e+26 2.57528639657e-12         -999 1.55960933147e-12
# 3.87078989053e+26 6.57930274899e-12         -999 1.78271377838e-12
# 6.37703585139e+26 2.87039290157e-12         -999 1.14556507684e-12
# 1.05060428246e+27 1.46046239229e-12         -999 1.46789101503e-12
#
# Output filename: MAGIC_2006_LSI61303_SPECTRUM.fits
# **********************************************************************
#
# ======================================================================
# Taking file:  nan
# Source name:  1ES1218+30.4
# Article:  http://adsabs.harvard.edu/cgi-bin/bib_query?arXiv:astro-ph/0603529
#
# ERROR:***: File opening failed. Moving on.
#
# ======================================================================
# Taking file:  FITS_pic/MAGIC_2006_HESS1834.fits
# Source name:  HESS J1834-087/W41
# Article:  http://adsabs.harvard.edu/cgi-bin/bib_query?arXiv:astro-ph/0604197
#
# ERROR:***: File opening failed. Moving on.
#
# ======================================================================
# Taking file:  FITS_pic/MAGIC_2006_HESS1813.fits
# Source name:  HESS J1813-178
# Article:  http://adsabs.harvard.edu/cgi-bin/bib_query?arXiv:astro-ph/0512283
#
# ----------------------------------------------------------------------
#
# Processing spectrum (DataUnit):  SPECTRUM
#
# Is EBL-correted?  False
#
# Resolved position (through Simbad):  (273.36292, -17.84889)
# Found position on fits header:  (273.408, -17.8677)
#
#       energy             flux       energy_error     flux_error
#         Hz          erg / (cm2 s)        Hz        erg / (cm2 s)
# ----------------- ----------------- ------------ -----------------
# 1.21762689678e+26 5.25370331476e-12         -999 1.32487288972e-12
# 1.92980938987e+26 5.51861603965e-12         -999 1.49781734447e-12
# 3.05853890821e+26 4.47585855644e-12         -999 1.23740117676e-12
# 4.84746414862e+26 5.81230990688e-12         -999 1.23639411368e-12
# 7.68270174039e+26 5.84001205236e-12         -999 1.30305260831e-12
# 1.21762689678e+27 3.27929553911e-12         -999 1.55119763924e-12
# 1.92980938987e+27 3.68531626681e-12         -999 1.56953075743e-12
#
# Output filename: MAGIC_2006_HESS1813_SPECTRUM.fits
# **********************************************************************
#
# ======================================================================
# Taking file:  nan
# Source name:  GRB050713a
# Article:  http://adsabs.harvard.edu/cgi-bin/bib_query?arXiv:astro-ph/0602231
#
# ERROR:***: File opening failed. Moving on.
#
# ======================================================================
# Taking file:  FITS_pic/MAGIC_2006_GC.fits
# Source name:  Galactic Center
# Article:  http://adsabs.harvard.edu/cgi-bin/bib_query?arXiv:astro-ph/0512469
#
# ----------------------------------------------------------------------
#
# Processing spectrum (DataUnit):  SPECTRUM
#
# Is EBL-correted?  False
#
# Resolved position (through Simbad):  (266.416833, -29.007806)
# Found position on fits header:  (266.4, -28.93)
#
#       energy             flux       energy_error     flux_error
#         Hz          erg / (cm2 s)        Hz        erg / (cm2 s)
# ----------------- ----------------- ------------ -----------------
# 1.45681440324e+26 5.09729982198e-12         -999 2.02476192578e-12
#  3.2507932414e+26 3.77072311307e-12         -999 1.24482513486e-12
# 7.25396804881e+26 4.50359816097e-12         -999  1.1776853315e-12
# 1.61868186427e+27 2.73887666291e-12         -999 8.86479037553e-13
# 3.61199249044e+27  3.1010244463e-12         -999 1.18997716442e-12
#
# Output filename: MAGIC_2006_GC_SPECTRUM.fits
# **********************************************************************
#
# ======================================================================
# Taking file:  nan
# Source name:  1ES1959+650
# Article:  http://adsabs.harvard.edu/cgi-bin/bib_query?arXiv:astro-ph/0508543
#
# ERROR:***: File opening failed. Moving on.
# /home/chbrandt/.conda/envs/magic/lib/python2.7/site-packages/IPython/kernel/__init__.py:13: ShimWarning: The `IPython.kernel` package has been deprecated. You should import from ipykernel or jupyter_client instead.
#   "You should import from ipykernel or jupyter_client instead.", ShimWarning)

# %%
table
# Out:
#                                     FITS                    SOURCE  \
# 0                                    NaN                   Mrk 421
# 1    FITS_pic/MAGIC_2015_CrabNebula.fits               Crab Nebula
# 2                                    NaN               PG 1553+113
# 3       FITS_pic/MAGIC_2015_1ES0806.fits              1ES 0806+524
# 4                                    NaN            HESS J1857+026
# 5                                    NaN                 J2001+439
# 6                                    NaN                   Mrk 501
# 7                                    NaN              1ES 0033+595
# 8         FITS_pic/MAGIC_2014_Ic310.fits                    IC 310
# 9   FITS_pic/MAGIC_2014_PKS1424+240.fits              PKS 1424+240
# 10         FITS_pic/MAGIC_2014_3C58.fits                     3C 58
# 11        FITS_pic/MAGIC_2014_AEaqr.fits                AE Aquarii
# 12                                   NaN              PKS 1510-089
# 13        FITS_pic/MAGIC_2014_3C279.fits                    3C 279
# 14      FITS_pic/MAGIC_2014_4C+5517.fits                 4C +55.17
# 15   FITS_pic/MAGIC_2014_CrabPulsar.fits               Crab Pulsar
# 16      FITS_pic/MAGIC_2014_NGC1275.fits                  NGC 1275
# 17                                   NaN               1ES 1727+50
# 18                                   NaN                 4C +21.35
# 19        FITS_pic/MAGIC_2014_IC310.fits                    IC 310
# 20       FITS_pic/MAGIC_2014_Segue1.fits                   Segue 1
# 21    FITS_pic/MAGIC_2014_GRB090102.fits                GRB 090102
# 22  FITS_pic/MAGIC_2013_1ES2344+514.fits              1ES 2344+514
# 23     FITS_pic/MAGIC_2013_J1644+57.fits            Swift J1644+57
# 24    FITS_pic/MAGIC_2013_Magnetars.fits  4U 0142+61, 1ES 2259+586
# 25      FITS_pic/MAGIC_2012_1ES1215.fits              1ES 1215+303
# 26          FITS_pic/MAGIC_2012_M87.fits                       M87
# 27      FITS_pic/MAGIC_2012_PKS2155.fits              PKS 2155-304
# 28                                   NaN            HESS J0632+057
# 29                                   NaN             Markarian 421
# ..                                   ...                       ...
# 69     FITS_pic/MAGIC_2008_WRBinSys.fits          WR Binary System
# 70        FITS_pic/MAGIC_2008_3C279.fits                    3C 279
# 71     FITS_pic/MAGIC_2009_LSI61303.fits              LS I +61 303
# 72          FITS_pic/MAGIC_2008_M87.fits                       M87
# 73                                   NaN               PG 1553+113
# 74  FITS_pic/MAGIC_2008_LSI61303_mw.fits              LS I +61 303
# 75        FITS_pic/MAGIC_2008_BLLac.fits                    BL Lac
# 76   FITS_pic/MAGIC_2008_1ES1959_mw.fits               1ES1959+650
# 77        FITS_pic/MAGIC_2008_Draco.fits                dSph Draco
# 78      FITS_pic/MAGIC_2008_TeV2032.fits            TeV J2032+4130
# 79         FITS_pic/MAGIC_2008_Crab.fits               Crab Pulsar
# 80      FITS_pic/MAGIC_2007_1ES1011.fits               1ES1011+496
# 81  FITS_pic/MAGIC_2007_CassiopeiaA.fits              Cassiopeia A
# 82        FITS_pic/MAGIC_2007_IC443.fits                    IC 443
# 83                                   NaN       PSR B1951+32/CTB 80
# 84                                   NaN             Markarian 501
# 85   FITS_pic/MAGIC_2007_BLLacertae.fits               BL Lacertae
# 86     FITS_pic/MAGIC_2007_CygnusX1.fits                Cygnus X-1
# 87       FITS_pic/MAGIC_2007_Mrk421.fits             Markarian 421
# 88                                   NaN              1ES 2344+514
# 89       FITS_pic/MAGIC_2007_Arp220.fits                   Arp 220
# 90                                   NaN               PG 1553+113
# 91       FITS_pic/MAGIC_2006_Mrk180.fits             Markarian 180
# 92     FITS_pic/MAGIC_2006_LSI61303.fits              LS I +61 303
# 93                                   NaN              1ES1218+30.4
# 94     FITS_pic/MAGIC_2006_HESS1834.fits        HESS J1834-087/W41
# 95     FITS_pic/MAGIC_2006_HESS1813.fits            HESS J1813-178
# 96                                   NaN                GRB050713a
# 97           FITS_pic/MAGIC_2006_GC.fits           Galactic Center
# 98                                   NaN               1ES1959+650
#
#                                                   URL  \
# 0   http://cdsads.u-strasbg.fr/abs/2014arXiv1412.3...
# 1   http://cdsads.u-strasbg.fr/abs/2014arXiv1406.6...
# 2   http://cdsads.u-strasbg.fr/abs/2014arXiv1408.1...
# 3   http://cdsads.u-strasbg.fr/abs/2015arXiv150406...
# 4   http://cdsads.u-strasbg.fr/abs/2014A%26A...571...
# 5   http://cdsads.u-strasbg.fr/abs/2014arXiv1409.3...
# 6   http://cdsads.u-strasbg.fr/abs/2014arXiv1410.6...
# 7   http://cdsads.u-strasbg.fr/abs/2014arXiv1410.7...
# 8   http://cdsads.u-strasbg.fr/abs/2014Sci...346.1...
# 9   http://cdsads.u-strasbg.fr/abs/2014arXiv1401.0...
# 10  http://cdsads.u-strasbg.fr/abs/2014arXiv1405.6...
# 11  http://cdsads.u-strasbg.fr/abs/2014arXiv1407.3...
# 12  http://cdsads.u-strasbg.fr/abs/2014arXiv1401.5...
# 13  http://cdsads.u-strasbg.fr/abs/2013arXiv1311.2...
# 14  http://cdsads.u-strasbg.fr/abs/2014MNRAS.440.....
# 15  http://cdsads.u-strasbg.fr/abs/2014A%26A...565...
# 16  http://cdsads.u-strasbg.fr/abs/2014A%26A...564...
# 17  http://cdsads.u-strasbg.fr/abs/2014A%26A...563...
# 18  http://cdsads.u-strasbg.fr/abs/2014ApJ...786.....
# 19  http://cdsads.u-strasbg.fr/abs/2014A%26A...563...
# 20  http://adsabs.harvard.edu/abs/2014JCAP...02..008A
# 21  http://adsabs.harvard.edu/abs/2014MNRAS.437.3103A
# 22  http://adsabs.harvard.edu/cgi-bin/bib_query?ar...
# 23  http://adsabs.harvard.edu/abs/2013A%26A...552A...
# 24  http://adsabs.harvard.edu/cgi-bin/bib_query?ar...
# 25  http://adsabs.harvard.edu/cgi-bin/bib_query?ar...
# 26  http://adsabs.harvard.edu/cgi-bin/bib_query?ar...
# 27  http://adsabs.harvard.edu/cgi-bin/bib_query?ar...
# 28  http://adsabs.harvard.edu/cgi-bin/bib_query?ar...
# 29  http://adsabs.harvard.edu/cgi-bin/bib_query?ar...
# ..                                                ...
# 69  http://adsabs.harvard.edu/cgi-bin/bib_query?ar...
# 70  http://www.sciencemag.org/content/320/5884/175...
# 71                     http://arxiv.org/abs/0806.1865
# 72  http://adsabs.harvard.edu/cgi-bin/bib_query?ar...
# 73       http://dx.doi.org/10.1051/0004-6361:20079048
# 74  http://adsabs.harvard.edu/cgi-bin/bib_query?ar...
# 75  http://adsabs.harvard.edu/cgi-bin/bib_query?ar...
# 76  http://adsabs.harvard.edu/cgi-bin/bib_query?ar...
# 77  http://adsabs.harvard.edu/cgi-bin/bib_query?ar...
# 78  http://adsabs.harvard.edu/cgi-bin/bib_query?ar...
# 79  http://adsabs.harvard.edu/cgi-bin/bib_query?ar...
# 80  http://adsabs.harvard.edu/cgi-bin/bib_query?ar...
# 81  http://adsabs.harvard.edu/cgi-bin/bib_query?ar...
# 82  http://adsabs.harvard.edu/cgi-bin/bib_query?ar...
# 83  http://adsabs.harvard.edu/cgi-bin/bib_query?ar...
# 84  http://adsabs.harvard.edu/cgi-bin/bib_query?ar...
# 85  http://adsabs.harvard.edu/cgi-bin/bib_query?ar...
# 86  http://adsabs.harvard.edu/cgi-bin/bib_query?ar...
# 87  http://adsabs.harvard.edu/cgi-bin/bib_query?ar...
# 88  http://adsabs.harvard.edu/cgi-bin/bib_query?ar...
# 89  http://adsabs.harvard.edu/cgi-bin/bib_query?ar...
# 90  http://adsabs.harvard.edu/cgi-bin/bib_query?ar...
# 91  http://adsabs.harvard.edu/cgi-bin/bib_query?ar...
# 92  http://adsabs.harvard.edu/cgi-bin/bib_query?ar...
# 93  http://adsabs.harvard.edu/cgi-bin/bib_query?ar...
# 94  http://adsabs.harvard.edu/cgi-bin/bib_query?ar...
# 95  http://adsabs.harvard.edu/cgi-bin/bib_query?ar...
# 96  http://adsabs.harvard.edu/cgi-bin/bib_query?ar...
# 97  http://adsabs.harvard.edu/cgi-bin/bib_query?ar...
# 98  http://adsabs.harvard.edu/cgi-bin/bib_query?ar...
#
#                                              SPECTRUM
# 0                                                None
# 1   [      energy             flux       energy_er...
# 2                                                None
# 3   [      energy             flux       energy_er...
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8   [      energy             flux       energy_er...
# 9   [      energy             flux       energy_er...
# 10  [      energy             flux          energy...
# 11                                               None
# 12                                               None
# 13  [      energy             flux       energy_er...
# 14  [      energy             flux       energy_er...
# 15  [      energy             flux       energy_er...
# 16  [      energy             flux       energy_er...
# 17                                               None
# 18                                               None
# 19  [      energy             flux       energy_er...
# 20  [      energy             flux       energy_er...
# 21  [      energy             flux       energy_er...
# 22                                                 []
# 23                                                 []
# 24  [      energy             flux       energy_er...
# 25  [      energy             flux       energy_er...
# 26  [      energy             flux          energy...
# 27  [      energy             flux       energy_er...
# 28                                               None
# 29                                               None
# ..                                                ...
# 69  [      energy             flux       energy_er...
# 70  [      energy             flux       energy_er...
# 71  [      energy             flux       energy_er...
# 72  [      energy             flux          energy...
# 73                                               None
# 74  [      energy             flux       energy_er...
# 75                                               None
# 76  [      energy             flux       energy_er...
# 77                                               None
# 78                                               None
# 79                                               None
# 80  [      energy             flux       energy_er...
# 81  [      energy             flux       energy_er...
# 82  [      energy             flux       energy_er...
# 83                                               None
# 84                                               None
# 85                                               None
# 86                                                 []
# 87  [      energy             flux       energy_er...
# 88                                               None
# 89                                               None
# 90                                               None
# 91  [      energy             flux       energy_er...
# 92  [      energy             flux       energy_er...
# 93                                               None
# 94                                               None
# 95  [      energy             flux       energy_er...
# 96                                               None
# 97  [      energy             flux       energy_er...
# 98                                               None
#
# [99 rows x 4 columns]

# %%
def fix_degeneracy(group):
    from collections import OrderedDict
    row = group.irow(0)
    columns = row.to_dict()
    specs = row['SPECTRUM']
    del columns['SPECTRUM']
    tdf = OrderedDict()
    tdf['OBJECT'] = []
    tdf['RA'] = []
    tdf['DEC'] = []
    tdf['DATE-OBS'] = []
    tdf['SPECTRUM'] = []
    tdf['SRCPOS1'] = []
    tdf['SRCPOS2'] = []
    tdf['EBL_CORR'] = []
    cnt = 0
    for s in specs:
        t = s.retrieve_table()
        tdf['RA'].append( t.meta['RA'] )
        tdf['DEC'].append( t.meta['DEC'] )
        tdf['OBJECT'].append( t.meta['OBJECT'] )
        tdf['DATE-OBS'].append( t.meta['DATE-OBS'] )
        tdf['SPECTRUM'].append( s )
        tdf['SRCPOS1'].append( t.meta['SRCPOS1'] )
        tdf['SRCPOS2'].append( t.meta['SRCPOS2'] )
        tdf['EBL_CORR'].append( t.meta['EBL_CORR'] )
        cnt += 1
    for c in columns:
        tdf[c] = [ row[c] ] * cnt
    return Local( tdf )

table_proc = table.dropna().groupby('URL',group_keys=False).apply(fix_degeneracy).reset_index(drop=True)
# Out:
# /home/chbrandt/.conda/envs/magic/lib/python2.7/site-packages/ipykernel/__main__.py:3: FutureWarning: irow(i) is deprecated. Please use .iloc[i]
#   app.launch_new_instance()

# %%
table_proc
# Out:
#            OBJECT          RA        DEC    DATE-OBS  \
# 0         Segue 1  151.763330  16.073610  2011-01-01
# 1         Segue 1  151.763330  16.073610  2011-01-01
# 2         Segue 1  151.763330  16.073610  2011-01-01
# 3         Segue 1  151.763330  16.073610  2011-01-01
# 4         Segue 1  151.763330  16.073610  2011-01-01
# 5         Segue 1  151.763330  16.073610  2011-01-01
# 6         Segue 1  151.763330  16.073610  2011-01-01
# 7         Segue 1  151.763330  16.073610  2011-01-01
# 8         Segue 1  151.763330  16.073610  2011-01-01
# 9         Segue 1  151.763330  16.073610  2011-01-01
# 10        Segue 1  151.763330  16.073610  2011-01-01
# 11        Segue 1  151.763330  16.073610  2011-01-01
# 12        Segue 1  151.763330  16.073610  2011-01-01
# 13        Segue 1  151.763330  16.073610  2011-01-01
# 14     GRB 090102  128.247917  33.107139  2009-01-02
# 15         IC 443   94.511250  22.660000  2005-12-01
# 16   Cassiopeia A  350.850000  58.815000  2006-06-01
# 17   1ES 1011+496  153.767249  49.433529  2007-03-12
# 18   1ES 1011+496  153.767249  49.433529  2007-03-12
# 19   LS I +61 303   40.131938  61.229337  2006-10-27
# 20   LS I +61 303   40.131938  61.229337  2006-10-27
# 21   1ES 1959+650  299.999384  65.148515  2006-05-21
# 16         energy             flux       energy_err...  350.863   58.815
# 17         energy             flux       energy_err...  153.768  49.4335
# 18         energy             flux       energy_err...  153.768  49.4335
# 19         energy             flux       energy_err...  40.1334   61.229
# 20         energy             flux       energy_err...  40.1334   61.229
# 21         energy             flux       energy_err...  299.998  65.1485
# 22         energy             flux          energy_...  187.706  12.3911
# 23         energy             flux       energy_err...  187.706  12.3911
# 24         energy             flux       energy_err...  187.706  12.3911
# 25         energy             flux       energy_err...     None     None
# 26         energy             flux       energy_err...     None     None
# 27         energy             flux       energy_err...  22.8994  16.1482
# 28         energy             flux       energy_err...  22.8994  16.1482
# 29         energy             flux       energy_err...  22.8994  16.1482
# ..                                                 ...      ...      ...
# 80         energy             flux       energy_err...     None     None
# 81         energy             flux       energy_err...     None     None
# 82         energy             flux       energy_err...     None     None
# 83         energy             flux       energy_err...     None     None
# 84         energy             flux       energy_err...     None     None
# 85         energy             flux       energy_err...     None     None
# 86         energy             flux       energy_err...     None     None
# 87         energy             flux       energy_err...     None     None
# 88         energy             flux       energy_err...     None     None
# 89         energy            flux       energy_erro...     None     None
# 90         energy             flux       energy_err...     None     None
# 91         energy             flux       energy_err...     None     None
# 92         energy             flux       energy_err...     None     None
# 93         energy             flux       energy_err...     None     None
# 94         energy             flux       energy_err...     None     None
# 95         energy             flux       energy_err...     None     None
# 96         energy             flux       energy_err...     None     None
# 97         energy             flux       energy_err...     None     None
# 98         energy             flux       energy_err...     None     None
# 99         energy             flux       energy_err...     None     None
# 100        energy             flux          energy_...     None     None
# 101        energy             flux       energy_err...     None     None
# 102        energy             flux       energy_err...     None     None
# 103        energy             flux       energy_err...     None     None
# 104        energy             flux       energy_err...     None     None
# 105        energy             flux       energy_err...     None     None
# 106        energy             flux       energy_err...     None     None
# 107        energy             flux       energy_err...  194.046   5.7893
# 108        energy             flux       energy_err...  194.046   5.7893
# 109        energy             flux       energy_err...  194.046   5.7893
#
#     EBL_CORR                                  FITS            SOURCE  \
# 0      FALSE       FITS_pic/MAGIC_2014_Segue1.fits           Segue 1
# 1      FALSE       FITS_pic/MAGIC_2014_Segue1.fits           Segue 1
# 2      FALSE       FITS_pic/MAGIC_2014_Segue1.fits           Segue 1
# 3      FALSE       FITS_pic/MAGIC_2014_Segue1.fits           Segue 1
# 4      FALSE       FITS_pic/MAGIC_2014_Segue1.fits           Segue 1
# 5      FALSE       FITS_pic/MAGIC_2014_Segue1.fits           Segue 1
# 6      FALSE       FITS_pic/MAGIC_2014_Segue1.fits           Segue 1
# 7      FALSE       FITS_pic/MAGIC_2014_Segue1.fits           Segue 1
# 8      FALSE       FITS_pic/MAGIC_2014_Segue1.fits           Segue 1
# 9      FALSE       FITS_pic/MAGIC_2014_Segue1.fits           Segue 1
# 10     FALSE       FITS_pic/MAGIC_2014_Segue1.fits           Segue 1
# 11     FALSE       FITS_pic/MAGIC_2014_Segue1.fits           Segue 1
# 12     FALSE       FITS_pic/MAGIC_2014_Segue1.fits           Segue 1
# 13     FALSE       FITS_pic/MAGIC_2014_Segue1.fits           Segue 1
# 14     FALSE    FITS_pic/MAGIC_2014_GRB090102.fits        GRB 090102
# 15     FALSE        FITS_pic/MAGIC_2007_IC443.fits            IC 443
# 16     FALSE  FITS_pic/MAGIC_2007_CassiopeiaA.fits      Cassiopeia A
# 17     FALSE      FITS_pic/MAGIC_2007_1ES1011.fits       1ES1011+496
# 18     FALSE      FITS_pic/MAGIC_2007_1ES1011.fits       1ES1011+496
# 19     FALSE  FITS_pic/MAGIC_2008_LSI61303_mw.fits      LS I +61 303
# 20     FALSE  FITS_pic/MAGIC_2008_LSI61303_mw.fits      LS I +61 303
# 21     FALSE   FITS_pic/MAGIC_2008_1ES1959_mw.fits       1ES1959+650
# 22     FALSE          FITS_pic/MAGIC_2008_M87.fits               M87
# 23     FALSE          FITS_pic/MAGIC_2008_M87.fits               M87
# 24     FALSE          FITS_pic/MAGIC_2008_M87.fits               M87
# 25     FALSE     FITS_pic/MAGIC_2008_WRBinSys.fits  WR Binary System
# 26     FALSE     FITS_pic/MAGIC_2008_WRBinSys.fits  WR Binary System
# 27     FALSE        FITS_pic/MAGIC_2009_3C454.fits          3C 454.3
# 28     FALSE        FITS_pic/MAGIC_2009_3C454.fits          3C 454.3
# 29     FALSE        FITS_pic/MAGIC_2009_3C454.fits          3C 454.3
# ..       ...                                   ...               ...
# 80     FALSE        FITS_pic/MAGIC_2014_IC310.fits            IC 310
# 81      TRUE        FITS_pic/MAGIC_2014_IC310.fits            IC 310
# 82     FALSE      FITS_pic/MAGIC_2014_NGC1275.fits          NGC 1275
# 83     FALSE      FITS_pic/MAGIC_2014_NGC1275.fits          NGC 1275
# 84     FALSE   FITS_pic/MAGIC_2014_CrabPulsar.fits       Crab Pulsar
# 85     FALSE   FITS_pic/MAGIC_2014_CrabPulsar.fits       Crab Pulsar
# 86     FALSE   FITS_pic/MAGIC_2014_CrabPulsar.fits       Crab Pulsar
# 87     FALSE   FITS_pic/MAGIC_2014_CrabPulsar.fits       Crab Pulsar
# 88     FALSE   FITS_pic/MAGIC_2014_CrabPulsar.fits       Crab Pulsar
# 89     FALSE   FITS_pic/MAGIC_2014_CrabPulsar.fits       Crab Pulsar
# 90     FALSE   FITS_pic/MAGIC_2014_CrabPulsar.fits       Crab Pulsar
# 91     FALSE   FITS_pic/MAGIC_2014_CrabPulsar.fits       Crab Pulsar
# 92     FALSE   FITS_pic/MAGIC_2014_CrabPulsar.fits       Crab Pulsar
# 93     FALSE      FITS_pic/MAGIC_2014_4C+5517.fits         4C +55.17
# 94     FALSE        FITS_pic/MAGIC_2014_Ic310.fits            IC 310
# 95      TRUE        FITS_pic/MAGIC_2014_Ic310.fits            IC 310
# 96     FALSE  FITS_pic/MAGIC_2014_PKS1424+240.fits      PKS 1424+240
# 97     FALSE  FITS_pic/MAGIC_2014_PKS1424+240.fits      PKS 1424+240
# 98     FALSE  FITS_pic/MAGIC_2014_PKS1424+240.fits      PKS 1424+240
# 99     FALSE  FITS_pic/MAGIC_2014_PKS1424+240.fits      PKS 1424+240
# 100    FALSE         FITS_pic/MAGIC_2014_3C58.fits             3C 58
# 101    FALSE   FITS_pic/MAGIC_2015_CrabNebula.fits       Crab Nebula
# 102    FALSE   FITS_pic/MAGIC_2015_CrabNebula.fits       Crab Nebula
# 103    FALSE      FITS_pic/MAGIC_2015_1ES0806.fits      1ES 0806+524
# 104    FALSE      FITS_pic/MAGIC_2015_1ES0806.fits      1ES 0806+524
# 105    FALSE      FITS_pic/MAGIC_2015_1ES0806.fits      1ES 0806+524
# 106    FALSE      FITS_pic/MAGIC_2015_1ES0806.fits      1ES 0806+524
# 107    FALSE        FITS_pic/MAGIC_2008_3C279.fits            3C 279
# 108     TRUE        FITS_pic/MAGIC_2008_3C279.fits            3C 279
# 109     TRUE        FITS_pic/MAGIC_2008_3C279.fits            3C 279
#
#                                                    URL
# 0    http://adsabs.harvard.edu/abs/2014JCAP...02..008A
# 1    http://adsabs.harvard.edu/abs/2014JCAP...02..008A
# 2    http://adsabs.harvard.edu/abs/2014JCAP...02..008A
# 3    http://adsabs.harvard.edu/abs/2014JCAP...02..008A
# 4    http://adsabs.harvard.edu/abs/2014JCAP...02..008A
# 5    http://adsabs.harvard.edu/abs/2014JCAP...02..008A
# 6    http://adsabs.harvard.edu/abs/2014JCAP...02..008A
# 7    http://adsabs.harvard.edu/abs/2014JCAP...02..008A
# 8    http://adsabs.harvard.edu/abs/2014JCAP...02..008A
# 9    http://adsabs.harvard.edu/abs/2014JCAP...02..008A
# 10   http://adsabs.harvard.edu/abs/2014JCAP...02..008A
# 11   http://adsabs.harvard.edu/abs/2014JCAP...02..008A
# 12   http://adsabs.harvard.edu/abs/2014JCAP...02..008A
# 13   http://adsabs.harvard.edu/abs/2014JCAP...02..008A
# 14   http://adsabs.harvard.edu/abs/2014MNRAS.437.3103A
# 15   http://adsabs.harvard.edu/cgi-bin/bib_query?ar...
# 16   http://adsabs.harvard.edu/cgi-bin/bib_query?ar...
# 17   http://adsabs.harvard.edu/cgi-bin/bib_query?ar...
# 18   http://adsabs.harvard.edu/cgi-bin/bib_query?ar...
# 19   http://adsabs.harvard.edu/cgi-bin/bib_query?ar...
# 20   http://adsabs.harvard.edu/cgi-bin/bib_query?ar...
# 21   http://adsabs.harvard.edu/cgi-bin/bib_query?ar...
# 22   http://adsabs.harvard.edu/cgi-bin/bib_query?ar...
# 23   http://adsabs.harvard.edu/cgi-bin/bib_query?ar...
# 24   http://adsabs.harvard.edu/cgi-bin/bib_query?ar...
# 25   http://adsabs.harvard.edu/cgi-bin/bib_query?ar...
# 26   http://adsabs.harvard.edu/cgi-bin/bib_query?ar...
# 27   http://adsabs.harvard.edu/cgi-bin/bib_query?ar...
# 28   http://adsabs.harvard.edu/cgi-bin/bib_query?ar...
# 29   http://adsabs.harvard.edu/cgi-bin/bib_query?ar...
# ..                                                 ...
# 80   http://cdsads.u-strasbg.fr/abs/2014A%26A...563...
# 81   http://cdsads.u-strasbg.fr/abs/2014A%26A...563...
# 82   http://cdsads.u-strasbg.fr/abs/2014A%26A...564...
# 83   http://cdsads.u-strasbg.fr/abs/2014A%26A...564...
# 84   http://cdsads.u-strasbg.fr/abs/2014A%26A...565...
# 85   http://cdsads.u-strasbg.fr/abs/2014A%26A...565...
# 86   http://cdsads.u-strasbg.fr/abs/2014A%26A...565...
# 87   http://cdsads.u-strasbg.fr/abs/2014A%26A...565...
# 88   http://cdsads.u-strasbg.fr/abs/2014A%26A...565...
# 89   http://cdsads.u-strasbg.fr/abs/2014A%26A...565...
# 90   http://cdsads.u-strasbg.fr/abs/2014A%26A...565...
# 91   http://cdsads.u-strasbg.fr/abs/2014A%26A...565...
# 92   http://cdsads.u-strasbg.fr/abs/2014A%26A...565...
# 93   http://cdsads.u-strasbg.fr/abs/2014MNRAS.440.....
# 94   http://cdsads.u-strasbg.fr/abs/2014Sci...346.1...
# 95   http://cdsads.u-strasbg.fr/abs/2014Sci...346.1...
# 96   http://cdsads.u-strasbg.fr/abs/2014arXiv1401.0...
# 97   http://cdsads.u-strasbg.fr/abs/2014arXiv1401.0...
# 98   http://cdsads.u-strasbg.fr/abs/2014arXiv1401.0...
# 99   http://cdsads.u-strasbg.fr/abs/2014arXiv1401.0...
# 100  http://cdsads.u-strasbg.fr/abs/2014arXiv1405.6...
# 101  http://cdsads.u-strasbg.fr/abs/2014arXiv1406.6...
# 102  http://cdsads.u-strasbg.fr/abs/2014arXiv1406.6...
# 103  http://cdsads.u-strasbg.fr/abs/2015arXiv150406...
# 104  http://cdsads.u-strasbg.fr/abs/2015arXiv150406...
# 105  http://cdsads.u-strasbg.fr/abs/2015arXiv150406...
# 106  http://cdsads.u-strasbg.fr/abs/2015arXiv150406...
# 107  http://www.sciencemag.org/content/320/5884/175...
# 108  http://www.sciencemag.org/content/320/5884/175...
# 109  http://www.sciencemag.org/content/320/5884/175...
#
# [110 rows x 11 columns]

# %%
outdir = 'FITS_out/'
clean_dir(outdir,'*')

for _spec in table_proc.SPECTRUM:
    write_to_fits(_spec,outdir)
#_bla = table_proc.apply(lambda d:write_to_fits(d.SPECTRUM,outdir),axis=1)
#del _bla

table_proc.describe()
# Out:
# WARNING: UnitsWarning: The unit 'erg' has been deprecated in the FITS standard. Suggested: cm2 g s-2. [astropy.units.format.utils]
# WARNING:astropy:UnitsWarning: The unit 'erg' has been deprecated in the FITS standard. Suggested: cm2 g s-2.
#                RA         DEC
# count  110.000000  110.000000
# mean   163.846798   30.964372
# std     88.553785   20.332647
# min     26.592530  -30.225588
# 25%     83.633083   16.148211
# 50%    152.765290   30.116843
# 75%    194.046527   41.324767
# max    350.850000   71.343434

# %%
import pandas as pd
pd.set_option('display.max_rows',200)
pd.set_option('display.max_columns',10)
pd.set_option('display.width',500)

print table_proc
# Out:
#                 OBJECT          RA        DEC    DATE-OBS                                           SPECTRUM                        ...                          SRCPOS2 EBL_CORR                                         FITS                                SOURCE                                                URL
# 0              Segue 1  151.763330  16.073610  2011-01-01        energy             flux       energy_err...                        ...                          16.0819    FALSE              FITS_pic/MAGIC_2014_Segue1.fits                               Segue 1  http://adsabs.harvard.edu/abs/2014JCAP...02..008A
# 1              Segue 1  151.763330  16.073610  2011-01-01        energy             flux       energy_err...                        ...                          16.0819    FALSE              FITS_pic/MAGIC_2014_Segue1.fits                               Segue 1  http://adsabs.harvard.edu/abs/2014JCAP...02..008A
# 2              Segue 1  151.763330  16.073610  2011-01-01        energy             flux       energy_err...                        ...                          16.0819    FALSE              FITS_pic/MAGIC_2014_Segue1.fits                               Segue 1  http://adsabs.harvard.edu/abs/2014JCAP...02..008A
# 3              Segue 1  151.763330  16.073610  2011-01-01        energy             flux       energy_err...                        ...                          16.0819    FALSE              FITS_pic/MAGIC_2014_Segue1.fits                               Segue 1  http://adsabs.harvard.edu/abs/2014JCAP...02..008A
# 4              Segue 1  151.763330  16.073610  2011-01-01        energy             flux       energy_err...                        ...                          16.0819    FALSE              FITS_pic/MAGIC_2014_Segue1.fits                               Segue 1  http://adsabs.harvard.edu/abs/2014JCAP...02..008A
# 5              Segue 1  151.763330  16.073610  2011-01-01        energy             flux       energy_err...                        ...                          16.0819    FALSE              FITS_pic/MAGIC_2014_Segue1.fits                               Segue 1  http://adsabs.harvard.edu/abs/2014JCAP...02..008A
# 6              Segue 1  151.763330  16.073610  2011-01-01        energy             flux       energy_err...                        ...                          16.0819    FALSE              FITS_pic/MAGIC_2014_Segue1.fits                               Segue 1  http://adsabs.harvard.edu/abs/2014JCAP...02..008A
# 7              Segue 1  151.763330  16.073610  2011-01-01        energy             flux       energy_err...                        ...                          16.0819    FALSE              FITS_pic/MAGIC_2014_Segue1.fits                               Segue 1  http://adsabs.harvard.edu/abs/2014JCAP...02..008A
# 8              Segue 1  151.763330  16.073610  2011-01-01        energy             flux       energy_err...                        ...                          16.0819    FALSE              FITS_pic/MAGIC_2014_Segue1.fits                               Segue 1  http://adsabs.harvard.edu/abs/2014JCAP...02..008A
# 9              Segue 1  151.763330  16.073610  2011-01-01        energy             flux       energy_err...                        ...                          16.0819    FALSE              FITS_pic/MAGIC_2014_Segue1.fits                               Segue 1  http://adsabs.harvard.edu/abs/2014JCAP...02..008A
# 10             Segue 1  151.763330  16.073610  2011-01-01        energy             flux       energy_err...                        ...                          16.0819    FALSE              FITS_pic/MAGIC_2014_Segue1.fits                               Segue 1  http://adsabs.harvard.edu/abs/2014JCAP...02..008A
# 11             Segue 1  151.763330  16.073610  2011-01-01        energy             flux       energy_err...                        ...                          16.0819    FALSE              FITS_pic/MAGIC_2014_Segue1.fits                               Segue 1  http://adsabs.harvard.edu/abs/2014JCAP...02..008A
# 12             Segue 1  151.763330  16.073610  2011-01-01        energy             flux       energy_err...                        ...                          16.0819    FALSE              FITS_pic/MAGIC_2014_Segue1.fits                               Segue 1  http://adsabs.harvard.edu/abs/2014JCAP...02..008A
# 13             Segue 1  151.763330  16.073610  2011-01-01        energy             flux       energy_err...                        ...                          16.0819    FALSE              FITS_pic/MAGIC_2014_Segue1.fits                               Segue 1  http://adsabs.harvard.edu/abs/2014JCAP...02..008A
# 14          GRB 090102  128.247917  33.107139  2009-01-02        energy             flux       energy_err...                        ...                           37.283    FALSE           FITS_pic/MAGIC_2014_GRB090102.fits                            GRB 090102  http://adsabs.harvard.edu/abs/2014MNRAS.437.3103A
# 15              IC 443   94.511250  22.660000  2005-12-01        energy             flux       energy_err...                        ...                             22.6    FALSE               FITS_pic/MAGIC_2007_IC443.fits                                IC 443  http://adsabs.harvard.edu/cgi-bin/bib_query?ar...
# 16        Cassiopeia A  350.850000  58.815000  2006-06-01        energy             flux       energy_err...                        ...                           58.815    FALSE         FITS_pic/MAGIC_2007_CassiopeiaA.fits                          Cassiopeia A  http://adsabs.harvard.edu/cgi-bin/bib_query?ar...
# 17        1ES 1011+496  153.767249  49.433529  2007-03-12        energy             flux       energy_err...                        ...                          49.4335    FALSE             FITS_pic/MAGIC_2007_1ES1011.fits                           1ES1011+496  http://adsabs.harvard.edu/cgi-bin/bib_query?ar...
# 18        1ES 1011+496  153.767249  49.433529  2007-03-12        energy             flux       energy_err...                        ...                          49.4335    FALSE             FITS_pic/MAGIC_2007_1ES1011.fits                           1ES1011+496  http://adsabs.harvard.edu/cgi-bin/bib_query?ar...
# 19        LS I +61 303   40.131938  61.229337  2006-10-27        energy             flux       energy_err...                        ...                           61.229    FALSE         FITS_pic/MAGIC_2008_LSI61303_mw.fits                          LS I +61 303  http://adsabs.harvard.edu/cgi-bin/bib_query?ar...
# 20        LS I +61 303   40.131938  61.229337  2006-10-27        energy             flux       energy_err...                        ...                           61.229    FALSE         FITS_pic/MAGIC_2008_LSI61303_mw.fits                          LS I +61 303  http://adsabs.harvard.edu/cgi-bin/bib_query?ar...
# 21        1ES 1959+650  299.999384  65.148515  2006-05-21        energy             flux       energy_err...                        ...                          65.1485    FALSE          FITS_pic/MAGIC_2008_1ES1959_mw.fits                           1ES1959+650  http://adsabs.harvard.edu/cgi-bin/bib_query?ar...
#
energy             flux          energy_...                        ...                          38.6667     TRUE       FITS_pic/MAGIC_2010_Mrk421_mw2006.fits                         Markarian 421  http://adsabs.harvard.edu/cgi-bin/bib_query?ar...
# 43       Markarian 421  166.113808  38.208833  2006-04-28        energy             flux          energy_...                        ...                          38.6667     TRUE       FITS_pic/MAGIC_2010_Mrk421_mw2006.fits                         Markarian 421  http://adsabs.harvard.edu/cgi-bin/bib_query?ar...
# 44       Markarian 421  166.113808  38.208833  2006-04-29        energy             flux          energy_...                        ...                          38.6667     TRUE       FITS_pic/MAGIC_2010_Mrk421_mw2006.fits                         Markarian 421  http://adsabs.harvard.edu/cgi-bin/bib_query?ar...
# 45       Markarian 421  166.113808  38.208833  2006-04-30        energy             flux          energy_...                        ...                          38.6667     TRUE       FITS_pic/MAGIC_2010_Mrk421_mw2006.fits                         Markarian 421  http://adsabs.harvard.edu/cgi-bin/bib_query?ar...
# 46       Markarian 421  166.113808  38.208833  2006-06-14        energy             flux          energy_...                        ...                          38.6667     TRUE       FITS_pic/MAGIC_2010_Mrk421_mw2006.fits                         Markarian 421  http://adsabs.harvard.edu/cgi-bin/bib_query?ar...
# 47          Cygnus X-3  308.107417  40.957750  2006-03-23        energy             flux       energy_err...                        ...                          40.9577    FALSE            FITS_pic/MAGIC_2010_CygnusX3.fits                            Cygnus X-3  http://adsabs.harvard.edu/cgi-bin/bib_query?ar...
# 48          Cygnus X-3  308.107417  40.957750  2006-03-23        energy             flux       energy_err...                        ...                          40.9577    FALSE            FITS_pic/MAGIC_2010_CygnusX3.fits                            Cygnus X-3  http://adsabs.harvard.edu/cgi-bin/bib_query?ar...
# 49          Cygnus X-3  308.107417  40.957750  2006-03-23        energy             flux       energy_err...                        ...                          40.9577    FALSE            FITS_pic/MAGIC_2010_CygnusX3.fits                            Cygnus X-3  http://adsabs.harvard.edu/cgi-bin/bib_query?ar...
# 50   1FGL J1954.3+2836  298.579792  28.601670  2009-07-01        energy             flux       energy_err...                        ...                             None    FALSE      FITS_pic/MAGIC_2010_MilagroSNR_G65.fits  1FGL J1954.3+2836, 1FGL J1958.6+2845  http://adsabs.harvard.edu/cgi-bin/bib_query?ar...
# 51   1FGL J1954.3+2836  298.579792  28.601670  2009-07-01        energy             flux       energy_err...                        ...                             None    FALSE      FITS_pic/MAGIC_2010_MilagroSNR_G65.fits  1FGL J1954.3+2836, 1FGL J1958.6+2845  http://adsabs.harvard.edu/cgi-bin/bib_query?ar...
# 52   1FGL J1958.6+2845  299.666700  28.765000  2009-07-01        energy             flux       energy_err...                        ...                             None    FALSE      FITS_pic/MAGIC_2010_MilagroSNR_G65.fits  1FGL J1954.3+2836, 1FGL J1958.6+2845  http://adsabs.harvard.edu/cgi-bin/bib_query?ar...
# 53              IC 310   49.179271  41.324767  2009-10-01        energy             flux       energy_err...                        ...                          41.3248    FALSE               FITS_pic/MAGIC_2010_IC310.fits                                IC 310  http://adsabs.harvard.edu/cgi-bin/bib_query?ar...
# 54         PKS 1222+21  186.226920  21.379562  2010-06-17        energy             flux       energy_err...                        ...                          21.3796    FALSE             FITS_pic/MAGIC_2011_PKS1222.fits                           PKS 1222+21  http://adsabs.harvard.edu/cgi-bin/bib_query?ar...
# 55         PKS 1222+21  186.226920  21.379562  2010-06-17        energy             flux       energy_err...                        ...                          21.3796     TRUE             FITS_pic/MAGIC_2011_PKS1222.fits                           PKS 1222+21  http://adsabs.harvard.edu/cgi-bin/bib_query?ar...
# 56     Perseus Cluster   49.946670  41.513060  2009-10-01        energy             flux       energy_err...                        ...                          41.5131    FALSE             FITS_pic/MAGIC_2012_Perseus.fits                       Perseus Cluster  http://adsabs.harvard.edu/cgi-bin/bib_query?ar...
# 57     Perseus Cluster   49.946670  41.513060  2009-10-01        energy             flux       energy_err...                        ...                          41.5131    FALSE             FITS_pic/MAGIC_2012_Perseus.fits                       Perseus Cluster  http://adsabs.harvard.edu/cgi-bin/bib_query?ar...
# 58         B3 2247+381  342.523951  38.410332  2010-09-30        energy             flux       energy_err...                        ...                          38.4103    FALSE              FITS_pic/MAGIC_2012_B32247.fits                           B3 2247+381  http://adsabs.harvard.edu/cgi-bin/bib_query?ar...
# 59         B3 2247+381  342.523951  38.410332  2010-09-30        energy             flux       energy_err...                        ...                          38.4103    FALSE              FITS_pic/MAGIC_2012_B32247.fits                           B3 2247+381  http://adsabs.harvard.edu/cgi-bin/bib_query?ar...
# 60        1ES 1215+303  184.467008  30.116843  1999-01-01        energy             flux       energy_err...                        ...                          30.1168    FALSE             FITS_pic/MAGIC_2012_1ES1215.fits                          1ES 1215+303  http://adsabs.harvard.edu/cgi-bin/bib_query?ar...
# 61        1ES 1215+303  184.467008  30.116843  1999-01-01        energy             flux       energy_err...                        ...                          30.1168    FALSE             FITS_pic/MAGIC_2012_1ES1215.fits                          1ES 1215+303  http://adsabs.harvard.edu/cgi-bin/bib_query?ar...
# 62         Crab Nebula   83.633083  22.014500  2007-10-01        energy             flux       energy_err...                        ...                             None    FALSE             FITS_pic/MAGIC_2012_PKS2155.fits                          PKS 2155-304  http://adsabs.harvard.edu/cgi-bin/bib_query?ar...
# 63        PKS 2155-304  329.716938 -30.225588  2006-07-28        energy             flux       energy_err...                        ...                             None    FALSE             FITS_pic/MAGIC_2012_PKS2155.fits                          PKS 2155-304  http://adsabs.harvard.edu/cgi-bin/bib_query?ar...
# 64                 M87  187.705931  12.391123  2005-03-15        energy             flux          energy_...                        ...                          12.3911    FALSE                 FITS_pic/MAGIC_2012_M87.fits                                   M87  http://adsabs.harvard.edu/cgi-bin/bib_query?ar...
# 65          4U 0142+61   26.592530  61.751060  2008-08-01        energy             flux       energy_err...                        ...                             None    FALSE           FITS_pic/MAGIC_2013_Magnetars.fits              4U 0142+61, 1ES 2259+586  http://adsabs.harvard.edu/cgi-bin/bib_query?ar...
# 66         1E 2259+586  345.283910  58.879040  2010-08-01        energy             flux       energy_err...                        ...                             None    FALSE           FITS_pic/MAGIC_2013_Magnetars.fits              4U 0142+61, 1ES 2259+586  http://adsabs.harvard.edu/cgi-bin/bib_query?ar...
# 67      HESS J1813-178  273.362920 -17.848890  2005-06-01        energy             flux       energy_err...                        ...                         -17.8677    FALSE            FITS_pic/MAGIC_2006_HESS1813.fits                        HESS J1813-178  http://adsabs.harvard.edu/cgi-bin/bib_query?ar...
# 68     Galactic Center  266.416833 -29.007806  2005-06-01        energy             flux       energy_err...                        ...                           -28.93    FALSE                  FITS_pic/MAGIC_2006_GC.fits                       Galactic Center  http://adsabs.harvard.edu/cgi-bin/bib_query?ar...
# 69       Markarian 421  166.113808  38.208833  2004-11-01        energy             flux       energy_err...                        ...                          38.1947    FALSE              FITS_pic/MAGIC_2007_Mrk421.fits                         Markarian 421  http://adsabs.harvard.edu/cgi-bin/bib_query?ar...
# 70       Markarian 421  166.113808  38.208833  2004-11-01        energy             flux       energy_err...                        ...                          38.1947    FALSE              FITS_pic/MAGIC_2007_Mrk421.fits                         Markarian 421  http://adsabs.harvard.edu/cgi-bin/bib_query?ar...
# 71        LS I +61 303   40.131938  61.229337  2005-10-11        energy             flux       energy_err...                        ...                           61.229    FALSE            FITS_pic/MAGIC_2006_LSI61303.fits                          LS I +61 303  http://adsabs.harvard.edu/cgi-bin/bib_query?ar...
# 72             Mrk 180  174.110035  70.157585  2006-03-23        energy             flux       energy_err...                        ...                          70.1576    FALSE              FITS_pic/MAGIC_2006_Mrk180.fits                         Markarian 180  http://adsabs.harvard.edu/cgi-bin/bib_query?ar...
# 73             Mrk 180  174.110035  70.157585  2006-03-23        energy             flux       energy_err...                        ...                          70.1576    FALSE              FITS_pic/MAGIC_2006_Mrk180.fits                         Markarian 180  http://adsabs.harvard.edu/cgi-bin/bib_query?ar...
# 74        LS I +61 303   40.131938  61.229337  2006-09-15        energy             flux       energy_err...                        ...                           61.229    FALSE            FITS_pic/MAGIC_2009_LSI61303.fits                          LS I +61 303                     http://arxiv.org/abs/0806.1865
# 75        LS I +61 303   40.131938  61.229337  2006-09-15        energy             flux       energy_err...                        ...                           61.229    FALSE            FITS_pic/MAGIC_2009_LSI61303.fits                          LS I +61 303                     http://arxiv.org/abs/0806.1865
# 76              3C 279  194.046527  -5.789312  2011-02-01        energy             flux       energy_err...                        ...                             None    FALSE               FITS_pic/MAGIC_2014_3C279.fits                                3C 279  http://cdsads.u-strasbg.fr/abs/2013arXiv1311.2...
# 77              3C 279  194.046527  -5.789312  2011-06-01        energy             flux       energy_err...                        ...                             None    FALSE               FITS_pic/MAGIC_2014_3C279.fits                                3C 279  http://cdsads.u-strasbg.fr/abs/2013arXiv1311.2...
# 78              IC 310   49.179271  41.324767  2009-10-01        energy             flux       energy_err...                        ...                             None    FALSE               FITS_pic/MAGIC_2014_IC310.fits                                IC 310  http://cdsads.u-strasbg.fr/abs/2014A%26A...563...
# 79              IC 310   49.179271  41.324767  2009-10-01        energy             flux       energy_err...                        ...                             None     TRUE               FITS_pic/MAGIC_2014_IC310.fits                                IC 310  http://cdsads.u-strasbg.fr/abs/2014A%26A...563...
#
http://cdsads.u-strasbg.fr/abs/2015arXiv150406...
# 106       1ES 0806+524  122.454945  52.316181  2011-01-01        energy             flux       energy_err...                        ...                             None    FALSE             FITS_pic/MAGIC_2015_1ES0806.fits                          1ES 0806+524  http://cdsads.u-strasbg.fr/abs/2015arXiv150406...
# 107             3C 279  194.046527  -5.789312  2006-02-23        energy             flux       energy_err...                        ...                           5.7893    FALSE               FITS_pic/MAGIC_2008_3C279.fits                                3C 279  http://www.sciencemag.org/content/320/5884/175...
# 108             3C 279  194.046527  -5.789312  2006-02-23        energy             flux       energy_err...                        ...                           5.7893     TRUE               FITS_pic/MAGIC_2008_3C279.fits                                3C 279  http://www.sciencemag.org/content/320/5884/175...
# 109             3C 279  194.046527  -5.789312  2006-02-23        energy             flux       energy_err...                        ...                           5.7893     TRUE               FITS_pic/MAGIC_2008_3C279.fits                                3C 279  http://www.sciencemag.org/content/320/5884/175...
#
# [110 rows x 11 columns]

# %%
table_final = table_proc.dropna()[['OBJECT','RA','DEC','URL','FITS','DATE-OBS']]
print table_final
# Out:
#               OBJECT          RA        DEC                                                URL                                         FITS    DATE-OBS
# 0            Segue 1  151.763330  16.073610  http://adsabs.harvard.edu/abs/2014JCAP...02..008A              FITS_pic/MAGIC_2014_Segue1.fits  2011-01-01
# 1            Segue 1  151.763330  16.073610  http://adsabs.harvard.edu/abs/2014JCAP...02..008A              FITS_pic/MAGIC_2014_Segue1.fits  2011-01-01
# 2            Segue 1  151.763330  16.073610  http://adsabs.harvard.edu/abs/2014JCAP...02..008A              FITS_pic/MAGIC_2014_Segue1.fits  2011-01-01
# 3            Segue 1  151.763330  16.073610  http://adsabs.harvard.edu/abs/2014JCAP...02..008A              FITS_pic/MAGIC_2014_Segue1.fits  2011-01-01
# 4            Segue 1  151.763330  16.073610  http://adsabs.harvard.edu/abs/2014JCAP...02..008A              FITS_pic/MAGIC_2014_Segue1.fits  2011-01-01
# 5            Segue 1  151.763330  16.073610  http://adsabs.harvard.edu/abs/2014JCAP...02..008A              FITS_pic/MAGIC_2014_Segue1.fits  2011-01-01
# 6            Segue 1  151.763330  16.073610  http://adsabs.harvard.edu/abs/2014JCAP...02..008A              FITS_pic/MAGIC_2014_Segue1.fits  2011-01-01
# 7            Segue 1  151.763330  16.073610  http://adsabs.harvard.edu/abs/2014JCAP...02..008A              FITS_pic/MAGIC_2014_Segue1.fits  2011-01-01
# 8            Segue 1  151.763330  16.073610  http://adsabs.harvard.edu/abs/2014JCAP...02..008A              FITS_pic/MAGIC_2014_Segue1.fits  2011-01-01
# 9            Segue 1  151.763330  16.073610  http://adsabs.harvard.edu/abs/2014JCAP...02..008A              FITS_pic/MAGIC_2014_Segue1.fits  2011-01-01
# 10           Segue 1  151.763330  16.073610  http://adsabs.harvard.edu/abs/2014JCAP...02..008A              FITS_pic/MAGIC_2014_Segue1.fits  2011-01-01
# 11           Segue 1  151.763330  16.073610  http://adsabs.harvard.edu/abs/2014JCAP...02..008A              FITS_pic/MAGIC_2014_Segue1.fits  2011-01-01
# 12           Segue 1  151.763330  16.073610  http://adsabs.harvard.edu/abs/2014JCAP...02..008A              FITS_pic/MAGIC_2014_Segue1.fits  2011-01-01
# 13           Segue 1  151.763330  16.073610  http://adsabs.harvard.edu/abs/2014JCAP...02..008A              FITS_pic/MAGIC_2014_Segue1.fits  2011-01-01
# 14        GRB 090102  128.247917  33.107139  http://adsabs.harvard.edu/abs/2014MNRAS.437.3103A           FITS_pic/MAGIC_2014_GRB090102.fits  2009-01-02
# 15            IC 443   94.511250  22.660000  http://adsabs.harvard.edu/cgi-bin/bib_query?ar...               FITS_pic/MAGIC_2007_IC443.fits  2005-12-01
# 16      Cassiopeia A  350.850000  58.815000  http://adsabs.harvard.edu/cgi-bin/bib_query?ar...         FITS_pic/MAGIC_2007_CassiopeiaA.fits  2006-06-01
# 17      1ES 1011+496  153.767249  49.433529  http://adsabs.harvard.edu/cgi-bin/bib_query?ar...             FITS_pic/MAGIC_2007_1ES1011.fits  2007-03-12
# 18      1ES 1011+496  153.767249  49.433529  http://adsabs.harvard.edu/cgi-bin/bib_query?ar...             FITS_pic/MAGIC_2007_1ES1011.fits  2007-03-12
# 19      LS I +61 303   40.131938  61.229337  http://adsabs.harvard.edu/cgi-bin/bib_query?ar...         FITS_pic/MAGIC_2008_LSI61303_mw.fits  2006-10-27
# 20      LS I +61 303   40.131938  61.229337  http://adsabs.harvard.edu/cgi-bin/bib_query?ar...         FITS_pic/MAGIC_2008_LSI61303_mw.fits  2006-10-27
# 21      1ES 1959+650  299.999384  65.148515  http://adsabs.harvard.edu/cgi-bin/bib_query?ar...          FITS_pic/MAGIC_2008_1ES1959_mw.fits  2006-05-21
# 22               M87  187.705931  12.391123  http://adsabs.harvard.edu/cgi-bin/bib_query?ar...                 FITS_pic/MAGIC_2008_M87.fits  2008-01-30
# 23               M87  187.705931  12.391123  http://adsabs.harvard.edu/cgi-bin/bib_query?ar...                 FITS_pic/MAGIC_2008_M87.fits  2008-01-30
# 24               M87  187.705931  12.391123  http://adsabs.harvard.edu/cgi-bin/bib_query?ar...                 FITS_pic/MAGIC_2008_M87.fits  2008-01-30
# 27           3C454.3  343.490617  16.148211  http://adsabs.harvard.edu/cgi-bin/bib_query?ar...               FITS_pic/MAGIC_2009_3C454.fits  2007-07-17
# 28           3C454.3  343.490617  16.148211  http://adsabs.harvard.edu/cgi-bin/bib_query?ar...               FITS_pic/MAGIC_2009_3C454.fits  2007-07-17
# 29           3C454.3  343.490617  16.148211  http://adsabs.harvard.edu/cgi-bin/bib_query?ar...               FITS_pic/MAGIC_2009_3C454.fits  2007-07-17
# 30               M13  250.423475  36.461319  http://adsabs.harvard.edu/cgi-bin/bib_query?ar...                 FITS_pic/MAGIC_2009_M13.fits  2007-06-12
# 31            OJ 287  133.703646  20.108511  http://adsabs.harvard.edu/cgi-bin/bib_query?ar...               FITS_pic/MAGIC_2009_OJ287.fits  2007-04-10
# 32            OJ 287  133.703646  20.108511  http://adsabs.harvard.edu/cgi-bin/bib_query?ar...               FITS_pic/MAGIC_2009_OJ287.fits  2007-04-10
# 33       S5 0716+714  110.472702  71.343434  http://adsabs.harvard.edu/cgi-bin/bib_query?ar...              FITS_pic/MAGIC_2009_S50716.fits  2008-04-22
# 34       S5 0716+714  110.472702  71.343434  http://adsabs.harvard.edu/cgi-bin/bib_query?ar...              FITS_pic/MAGIC_